# %%
# !pip install -r requirements.txt

# %%
from platform import python_version

from langchain_qdrant import QdrantVectorStore
from qdrant_client import QdrantClient
from langchain_openai import OpenAIEmbeddings
from qdrant_client.models import VectorParams, Distance
from dotenv import load_dotenv
load_dotenv()
import os

from typing import List, Optional
import os
from pathlib import Path

from langchain_community.document_loaders import PyPDFLoader, Docx2txtLoader
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.agents import create_agent

# %% [markdown]
# ### альтернативный вариант

# %%
from platform import python_version
import os
from pathlib import Path
from typing import List, Optional

from dotenv import load_dotenv
load_dotenv()

import re
import uuid
import pandas as pd

from qdrant_client import QdrantClient
from qdrant_client.models import VectorParams, Distance

from langchain_qdrant import QdrantVectorStore
from langchain_openai import OpenAIEmbeddings
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter, TokenTextSplitter

import clickhouse_connect

# (если понадобится) from langchain_community.document_loaders import PyPDFLoader, Docx2txtLoader

# %%
# 2.1 Настройка подключения к Qdrant
QDRANT_URL = os.getenv("QDRANT_URL")
client_qdrant = QdrantClient(url=QDRANT_URL)

# 2.2 Настройка подключения к ClickHouse
CH_HOST = '84.201.160.255'   # или из окружения
CH_PORT = 8123
CLICKHOUSE_USER = 'peter'
CLICKHOUSE_PASSWORD = '1234'

client_clickhouse = clickhouse_connect.get_client(
    host=CH_HOST,
    port=CH_PORT,
    username=CLICKHOUSE_USER,
    password=CLICKHOUSE_PASSWORD
)

# %%
emails_df = client_clickhouse.query_df("""
    SELECT id, message_id, subject, from_addr, to_addr, cc_addr, bcc_addr,
           sent_at_utc, folder, body_text, body_html
    FROM mailkb.emails
    ORDER BY sent_at_utc DESC, message_id DESC
    --LIMIT 100
""")

# %% [markdown]
# Настройка коллекции в Qdrant (с вариантами)

# %%
BASE_URL = "http://localhost:8000/v1"
embeddings = OpenAIEmbeddings(
    # model="Qwen/Qwen3-Embedding-8B",
    model="Qwen/Qwen3-Embedding-0.6B",
    api_key="not-needed",
    base_url=BASE_URL,
    tiktoken_enabled=False,
)

# %%
# тест - получаем размерность эмбединга
vec = embeddings.embed_query("test")
EMBEDDING_DIM = len(vec)
EMBEDDING_DIM
# Out:
# 1024

# %%
from qdrant_client import QdrantClient
from qdrant_client.models import VectorParams, Distance
from langchain_qdrant import QdrantVectorStore

COLLECTION_NAME = "mailkb_emails"


# ---------- Вариант A: УДАЛИТЬ коллекцию и СОЗДАТЬ ЗАНОВО ----------
def setup_collection_recreate():
    """
    Полная пересоздача коллекции: удаляем старую, создаём новую с нужной размерностью.
    Полезно, когда меняешь модель / размер эмбеддинга.
    """
    client_qdrant.recreate_collection(
        collection_name=COLLECTION_NAME,
        vectors_config=VectorParams(
            size=EMBEDDING_DIM,
            distance=Distance.COSINE,
        ),
    )

    qv = QdrantVectorStore(
        client=client_qdrant,
        collection_name=COLLECTION_NAME,
        embedding=embeddings,
        # если не хочешь, чтобы он дополнительно валидировал конфиг:
        # validate_collection_config=False,
    )
    return qv


# ---------- Вариант B: СОЗДАТЬ, если коллекции ещё нет ----------
def setup_collection_create_if_not_exists():
    """
    Если коллекции нет — создаём.
    Если есть — НЕ трогаем (данные сохраняются).
    """
    collections = client_qdrant.get_collections().collections
    existing_names = {c.name for c in collections}

    if COLLECTION_NAME not in existing_names:
        client_qdrant.create_collection(
            collection_name=COLLECTION_NAME,
            vectors_config=VectorParams(
                size=EMBEDDING_DIM,
                distance=Distance.COSINE,
            ),
        )

    qv = QdrantVectorStore(
        client=client_qdrant,
        collection_name=COLLECTION_NAME,
        embedding=embeddings,
        # при желании можно отключить проверку:
        # validate_collection_config=False,
    )
    return qv


# ---------- Вариант C: ИСПОЛЬЗОВАТЬ ТЕКУЩУЮ коллекцию как есть ----------
def setup_collection_use_existing():
    """
    Просто подключаемся к уже существующей коллекции.
    Ничего не создаём и не удаляем.
    Важно: размерность в Qdrant должна совпадать с размерностью эмбеддинга.
    """
    qv = QdrantVectorStore(
        client=client_qdrant,
        collection_name=COLLECTION_NAME,
        embedding=embeddings,
        # если вдруг Qdrant создан с "левым" размером, и ты осознанно хочешь
        # отключить проверку (НЕ рекомендую в бою):
        # validate_collection_config=False,
    )
    return qv

# %%
# Пример использования одного из вариантов:
# qv = setup_collection_recreate()
qv = setup_collection_create_if_not_exists()
# qv = setup_collection_use_existing()

# %% [markdown]
# Подготовка утилит (нормализация, участники, превращение в документы)

# %%
RE_PREFIX = re.compile(r'^\s*(re|fw|fwd):\s*', flags=re.IGNORECASE)

def normalize_subject(subj: str) -> str:
    s = subj or ""
    while True:
        ns = RE_PREFIX.sub('', s).strip()
        if ns == s:
            break
        s = ns
    s = re.sub(r'\s+', ' ', s)
    return s.lower()

def participants_list(row) -> list[str]:
    def _norm(x):
        if not x:
            return []
        if isinstance(x, list):
            return [str(i).strip() for i in x if str(i).strip()]
        return [p.strip() for p in re.split(r'[;,]', str(x)) if p.strip()]
    people = _norm(row.get("from_addr")) + _norm(row.get("to_addr")) \
           + _norm(row.get("cc_addr")) + _norm(row.get("bcc_addr"))
    return sorted(set(people))

def build_docs(df: pd.DataFrame) -> list[Document]:
    docs: list[Document] = []
    for _, r in df.iterrows():
        subj = (r.get("subject") or "").strip()
        body = (r.get("body_text") or "").strip()
        if not body:
            body = (r.get("body_html") or "").strip()
        text = (subj + "\n\n" + body).strip()
        if not text:
            continue
        parts = participants_list(r)
        norm_subj = normalize_subject(subj)
        thread_key = f"{norm_subj}||{';'.join(sorted(parts))}"
        meta = {
            "row_id": r.get("id"),
            "message_id": r.get("message_id"),
            "subject": subj,
            "sent_at_utc": str(r.get("sent_at_utc")),
            "folder": r.get("folder"),
            "from_addr": parts[:1],
            "participants": parts,
            "thread_key": thread_key,
        }
        docs.append(Document(page_content=text, metadata=meta))
    return docs

# %% [markdown]
# Очистка текста и разбивка на чанки

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=1200, chunk_overlap=150)

RE_QUOTED = re.compile(r"(?m)^(>+).*$")  # строки, начинающиеся с >
RE_HDR = re.compile(r"(?:^|\n)(from:|sent:|to:|subject:).*(?:\n.*){0,20}", re.IGNORECASE)

def clean_text(t: str) -> str:
    t = t.replace("\r\n", "\n")
    t = RE_HDR.sub("\n", t)
    t = RE_QUOTED.sub("", t)
    t = "\n".join([ln.strip() for ln in t.split("\n") if ln.strip()])
    return t

def preprocess_and_chunk(docs: list[Document]) -> list[Document]:
    cleaned: list[Document] = []
    for d in docs:
        txt = clean_text(d.page_content)
        if not txt:
            continue
        cleaned.append(Document(page_content=txt, metadata=d.metadata))
    return splitter.split_documents(cleaned)

# %% [markdown]
# Генерация стабильных ID и загрузка в Qdrant

# %%
def make_ids(chunks: list[Document]) -> list[str]:
    counters: dict[str, int] = {}
    ids: list[str] = []
    for c in chunks:
        msg = c.metadata.get("message_id") or c.metadata.get("row_id") or "noid"
        i = counters.get(msg, 0)
        counters[msg] = i + 1
        raw = f"{msg}::chunk_{i}"
        uid = uuid.uuid5(uuid.NAMESPACE_URL, raw)
        ids.append(str(uid))
    return ids

def process_batch(df: pd.DataFrame):
    docs = build_docs(df)
    chunks = preprocess_and_chunk(docs)
    if not chunks:
        return
    ids = make_ids(chunks)
    texts = [c.page_content for c in chunks]
    metadatas = [c.metadata for c in chunks]
    qv.add_texts(texts=texts, metadatas=metadatas, ids=ids)

# %% [markdown]
# Запуск загрузки (батчинг)

# %%
# полный цикл с батчингом
# BATCH_SIZE = 5000
# offset = 0
#
# while True:
#     df_batch = client_clickhouse.query_df(f"""
#         SELECT id, message_id, subject, from_addr, to_addr, cc_addr, bcc_addr,
#                sent_at_utc, folder, body_text, body_html
#         FROM mailkb.emails
#         ORDER BY sent_at_utc ASC
#         LIMIT {BATCH_SIZE} OFFSET {offset}
#     """)
#     if df_batch.empty:
#         break
#     process_batch(df_batch)
#     offset += len(df_batch)
#     print(f"Processed {offset} rows")

# Или — одноразовая загрузка небольшой выборки
offset = 0
df_small = client_clickhouse.query_df("""
    SELECT id, message_id, subject, from_addr, to_addr, cc_addr, bcc_addr,
           sent_at_utc, folder, body_text, body_html
    FROM mailkb.emails
    ORDER BY sent_at_utc DESC, message_id DESC
    LIMIT 100
""")
process_batch(df_small)
offset += len(df_small)

# %% [markdown]
# Аналитика переписки (треды, темы, теги проектов)

# %%
from collections import Counter
# Утилиты
def split_addrs(x) -> list[str]:
    if x is None:
        return []
    if isinstance(x, list):
        return [a.strip() for a in x if str(a).strip()]
    return [a.strip() for a in re.split(r'[;,]', str(x)) if a.strip()]

def participants(row) -> list[str]:
    lst = split_addrs(row.get("from_addr")) + split_addrs(row.get("to_addr")) \
        + split_addrs(row.get("cc_addr")) + split_addrs(row.get("bcc_addr"))
    return sorted(set(lst))

def clean_for_topics(text: str) -> list[str]:
    if not text:
        return []
    t = text.lower()
    t = re.sub(r'[^a-zа-я0-9\s\-]+', ' ', t)
    t = re.sub(r'\s+', ' ', t).strip()
    toks = t.split()
    stop = set("""
        и в во на с со от до по за для при как что это это/that of the a an to is are was were be been being
        у о об обo про из из-за над под между но или либо либо/или который которые какая какие чей чья чей-то
        re fw fwd subject тема письмо письма письме по- поводу
    """.split())
    return [w for w in toks if len(w) > 2 and w not in stop]

PROJECT_KEYWORDS = {
    "segezha": "Проект: Segezha",
    "ewm": "SAP EWM",
    "bw": "SAP BW",
    "o2c": "O2C",
    "mnf": "MNF",
    "сцбк": "СЦБК",
    "вагон": "Логистика/Вагоны",
}

def guess_project_tags(subject: str, body: str, addrs: list[str]) -> list[str]:
    text = f"{subject or ''} {body or ''}".lower()
    tags = set()
    for kw, tag in PROJECT_KEYWORDS.items():
        if kw in text:
            tags.add(tag)
    for a in addrs:
        m = re.search(r'@([a-z0-9\.-]+)', a.lower())
        if m:
            dom = m.group(1)
            if 'segezha' in dom:
                tags.add("Проект: Segezha")
            if 'bearingpoint' in dom:
                tags.add("Внутренние/Подрядчик")
    return sorted(tags)

# Добавление колонок в df
df = emails_df.copy()
df["norm_subject"] = df["subject"].apply(lambda s: normalize_subject(s if isinstance(s, str) else ""))
df["participants"] = df.apply(participants, axis=1)
df["thread_key"] = df.apply(lambda r: f'{r["norm_subject"]}||{";".join(r["participants"])}', axis=1)

def plain_body(row):
    t = (row.get("body_text") or "").strip()
    if t:
        return t
    return (row.get("body_html") or "").strip()

df["plain_body"] = df.apply(plain_body, axis=1)
df["topics"] = df.apply(lambda r: clean_for_topics(r["subject"]) + clean_for_topics(r["plain_body"][:1000]), axis=1)
df["project_tags"] = df.apply(lambda r: guess_project_tags(r["subject"], r["plain_body"], r["participants"]), axis=1)

threads = (
    df.groupby("thread_key")
      .agg(
         first_sent=("sent_at_utc","min"),
         last_sent=("sent_at_utc","max"),
         n_emails=("id","count"),
         subjects=("subject", lambda s: list(pd.unique([x for x in s if isinstance(x, str)]))[:5]),
         participants=("participants", lambda cols: sorted(set(sum(cols, [])))),
         projects=("project_tags", lambda cols: sorted(set(sum(cols, [])))),
         topics=("topics", lambda cols: [w for w,_ in Counter(sum(cols, [])).most_common(10)])
      )
      .reset_index()
      .sort_values(["last_sent","n_emails"], ascending=[False, False])
)

def flatten(col):
    out = []
    for arr in col:
        out.extend(arr)
    return out

projects_df = (
    threads.assign(project=lambda x: x["projects"].apply(lambda arr: arr if arr else ["(Не классифицировано)"]))
           .explode("project")
           .groupby("project")
           .agg(
              n_threads=("thread_key","nunique"),
              n_emails=("n_emails","sum"),
              first_sent=("first_sent","min"),
              last_sent=("last_sent","max"),
              participants=("participants", lambda cols: sorted(set(flatten(cols)))[:50]),
              top_topics=("topics", lambda cols: [w for w,_ in Counter(flatten(cols)).most_common(15)])
           )
           .reset_index()
           .sort_values(["n_threads","n_emails"], ascending=[False, False])
)
# Out:
# C:\Users\Peter\AppData\Local\Temp\ipykernel_29396\3129374694.py:77: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   subjects=("subject", lambda s: list(pd.unique([x for x in s if isinstance(x, str)]))[:5]),

# %% [markdown]
# Сводка тредов с помощью LLM

# %% [markdown]
# ### Первый агент

# %%
import json
from collections import defaultdict
from langchain.tools import tool


@tool
def search_project_emails(project_hint: str, limit: int = 200) -> str:
    """
    Найти и сгруппировать письма по проекту/теме.

    Вход:
        project_hint: текстовая подсказка — название проекта, код ЗНИ, ключевые слова.
        limit: максимум писем для выборки.

    Логика:
      1) делаем семантический поиск по Qdrant;
      2) группируем результаты по thread_key;
      3) сортируем письма внутри треда по sent_at_utc.

    Выход:
        JSON-строка со структурой:
        {
          "project_hint": "...",
          "threads": [
            {
              "thread_key": "...",
              "subject": "...",
              "participants": [...],
              "messages": [
                {
                  "message_id": "...",
                  "sent_at_utc": "...",
                  "from_addr": "...",
                  "snippet": "...",
                  "subject": "...",
                  "folder": "...",
                  "participants": [...],
                  "metadata": {...}
                }
              ]
            }
          ]
        }
    """
    # 1. Семантический поиск по тексту
    docs = qv.similarity_search(project_hint, k=limit)

    threads = defaultdict(list)

    for doc in docs:
        md = doc.metadata or {}

        thread_key = md.get("thread_key") or md.get("subject") or "unknown_thread"

        message = {
            "row_id": md.get("row_id"),
            "message_id": md.get("message_id"),
            "sent_at_utc": md.get("sent_at_utc"),
            "from_addr": (md.get("from_addr") or [None])[0],
            "subject": md.get("subject"),
            "folder": md.get("folder"),
            "participants": md.get("participants") or [],
            # обрезаем тело, чтобы не заливать в ответ мегатекст
            "snippet": (doc.page_content[:600] + "…") if doc.page_content else None,
            "metadata": md,
        }

        threads[thread_key].append(message)

    thread_list = []
    for thread_key, messages in threads.items():
        # сортируем по дате
        messages_sorted = sorted(
            messages,
            key=lambda m: m.get("sent_at_utc") or "",
        )

        # subject — из какого-то письма (обычно это RE:/FW: и т.п.)
        subject = None
        for m in messages_sorted:
            if m.get("subject"):
                subject = m["subject"]
                break

        # участники: агрегируем по всем письмам
        participants_set = set()
        for m in messages_sorted:
            for p in m.get("participants") or []:
                participants_set.add(p)

        thread_list.append(
            {
                "thread_key": thread_key,
                "subject": subject,
                "participants": sorted(participants_set),
                "messages": messages_sorted,
            }
        )

    result = {
        "project_hint": project_hint,
        "threads": thread_list,
    }

    return json.dumps(result, ensure_ascii=False, indent=2)

# %%
@tool
def search_emails_raw(query: str, limit: int = 50) -> str:
    """
    Общий поиск писем в Qdrant по любому запросу (без группировки).
    Удобно для отладки.
    """
    docs = qv.similarity_search(query, k=limit)
    data = []
    for doc in docs:
        md = doc.metadata or {}
        data.append({
            "thread_key": md.get("thread_key"),
            "row_id": md.get("row_id"),
            "message_id": md.get("message_id"),
            "subject": md.get("subject"),
            "sent_at_utc": md.get("sent_at_utc"),
            "from_addr": (md.get("from_addr") or [None])[0],
            "participants": md.get("participants") or [],
            "folder": md.get("folder"),
            "snippet": (doc.page_content[:400] + "…") if doc.page_content else None,
        })
    return json.dumps({"query": query, "results": data}, ensure_ascii=False, indent=2)

# %%
@tool
def search_project_emails_batch(project_hint: str, offset: int = 0, batch_size: int = 50) -> str:
    """
    Возвращает batch данных по offset.
    """
    docs = qv.similarity_search(project_hint, k=offset + batch_size)
    docs = docs[offset: offset + batch_size]

    batch = []
    for d in docs:
        md = d.metadata or {}
        batch.append({
            "subject": md.get("subject"),
            "snippet": d.page_content[:600],
            "sent_at_utc": md.get("sent_at_utc"),
            "thread_key": md.get("thread_key"),
        })

    return json.dumps({
        "project_hint": project_hint,
        "offset": offset,
        "batch_size": batch_size,
        "batch_len": len(batch),
        "has_more": len(batch) == batch_size,
        "batch": batch
    }, ensure_ascii=False)

# %%
from pathlib import Path
import json
from langchain.tools import tool

SUMMARY_DIR = Path("summaries")
SUMMARY_DIR.mkdir(exist_ok=True)

@tool
def save_summary(summary_text: str, batch_id: int) -> str:
    """
    Сохраняет резюме батча в файл summaries/summary_batch_{id}.txt
    """
    p = SUMMARY_DIR / f"summary_batch_{batch_id}.txt"
    p.write_text(summary_text, encoding="utf-8")
    return f"saved_to={str(p)}"

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import (
    PIIMiddleware,
    SummarizationMiddleware,
)
# from langchain_tavily import TavilySearch  # если понадобится веб-поиск

SYSTEM_PROMPT = """
Ты — аналитик переписки по проектам.
Твоя задача — обработать всю переписку порциями (батчами), создать
summary каждого батча и сохранить его в файл через инструмент save_summary.
Итоговый общий отчёт по проекту делать НЕ нужно — это будет выполнять другой агент.

========================================
ОБЩИЙ АЛГОРИТМ РАБОТЫ
========================================

Шаг 1. Определи project_hint из вопроса пользователя
(например, “Segezha”, код ЗНИ, ключевые слова и т.д.)

Шаг 2. Запускай цикл обработки батчей:

  2.1. Вызови search_project_emails_batch(project_hint, offset, batch_size=50)

  2.2. Получи результаты батча:
        - batch (список объектов)
        - offset
        - has_more

  2.3. Сгенерируй summary ТОЛЬКО для этого батча:
        - выдели ключевые темы
        - промежуточные выводы
        - что обсуждалось
        - без глобальных итогов

  2.4. Вызови save_summary(summary_text, batch_id)
        batch_id — порядковый номер батча, начиная с 1

  2.5. Если has_more = true:
          offset = offset + batch_size
          перейди к шагу 2.1
       Иначе:
          завершить цикл и сообщить пользователю «Все батчи обработаны»
          (но НЕ делай итогового отчёта)

========================================
ОГРАНИЧЕНИЯ
========================================
- НЕ делай глобального анализа.
- НЕ формируй общий отчёт по проекту.
- НЕ агрегируй темы между батчами.
- Каждый batch должен быть сохранён отдельно.
- Работай строго по циклу batch → summary → save → next batch.

========================================
ПРИМЕЧАНИЯ
========================================
- В summary описывай только то, что есть внутри текущего batch.
- Запрещено запрашивать инструмент search_project_emails.
- Использовать нужно ТОЛЬКО search_project_emails_batch и save_summary.


"""

agent = create_agent(
    # model="gpt-5",  # или твой модельный endpoint
    # model="claude-sonnet-4-20250514",  # или твой модельный endpoint
    model= "deepseek-reasoner",  # или твой модельный endpoint


    tools=[
        # search_project_emails,
        search_project_emails_batch,
        save_summary,
        search_emails_raw,   # опционально
    ],
    system_prompt=SYSTEM_PROMPT,
    middleware=[
        # скрываем e-mail и телефоны в вводе/выводе (настраиваем по желанию)
        PIIMiddleware("email", strategy="redact", apply_to_input=True),
        PIIMiddleware(
            "phone_number",
            detector=(
                r"(?:\+?\d{1,3}[\s.-]?)?"
                r"(?:\(?\d{2,4}\)?[\s.-]?)?"
                r"\d{3,4}[\s.-]?\d{4}"
            ),
            strategy="redact",
        ),
        # если переписка большая, middleware будет автоматически её подрезать и резюмировать
        SummarizationMiddleware(
            model="gpt-5",
            # model="claude-sonnet-4-20250514",  # или твой модельный endpoint
            max_tokens_before_summary=500,
        ),
    ],
)

# %%
result = agent.invoke({
    "messages": [
        {
            "role": "user",
            "content": """Начни обработку проекта Segezha батчами.
            Делай summary каждого батча и сохраняй их через save_summary.
            Итоговый отчёт НЕ делай. """

        }
    ]
})

report = result["messages"][-1].content
print(report)
# Out:
# Все батчи обработаны

# %% [markdown]
# ### второй агент

# %%
from pathlib import Path
from langchain.tools import tool

SUMMARY_DIR = Path("summaries")
SUMMARY_DIR.mkdir(exist_ok=True)

@tool
def load_all_summaries() -> str:
    """
    Читает все файлы summary_batch_*.txt в каталоге summaries/.
    Возвращает один объединённый текст.
    """
    files = sorted(SUMMARY_DIR.glob("summary_batch_*.txt"))

    if not files:
        return "NO_SUMMARIES_FOUND"

    texts = []
    for file in files:
        content = file.read_text(encoding="utf-8")
        texts.append(f"===== {file.name} =====\n{content}\n")

    return "\n".join(texts)

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import (
    PIIMiddleware,
    SummarizationMiddleware,
)
# from langchain_tavily import TavilySearch  # если понадобится веб-поиск

SYSTEM_PROMPT = """
Ты — эксперт по агрегированию больших массивов информации.

Твоя задача — взять summary отдельных батчей (их подготовил другой агент),
и создать единый, структурированный глобальный отчет.

Алгоритм:

1) Вызови load_all_summaries().
2) Проведи глубокий анализ:
   - ключевые темы,
   - решения,
   - риски,
   - нерешённые вопросы,
   - повторяющиеся инциденты.

3) Выдай ОДИН финальный отчёт:

Структура:
1. Краткое резюме по проекту.
2. Основные темы.
3. Ключевые решения.
4. Проблемы и риски.
5. Повторяющиеся инциденты (объединённо).
6. Финальное резюме.

Не переписывай батчи дословно — делай смысловое сжатие.

"""

agent_global = create_agent(
    model="gpt-5",  # или твой модельный endpoint
    # model="claude-sonnet-4-20250514",  # или твой модельный endpoint

    tools=[
        # search_project_emails,
        search_project_emails_batch,
        save_summary,
        load_all_summaries,
        search_emails_raw,   # опционально
    ],
    system_prompt=SYSTEM_PROMPT,
    middleware=[
        # скрываем e-mail и телефоны в вводе/выводе (настраиваем по желанию)
        PIIMiddleware("email", strategy="redact", apply_to_input=True),
        PIIMiddleware(
            "phone_number",
            detector=(
                r"(?:\+?\d{1,3}[\s.-]?)?"
                r"(?:\(?\d{2,4}\)?[\s.-]?)?"
                r"\d{3,4}[\s.-]?\d{4}"
            ),
            strategy="redact",
        ),
        # если переписка большая, middleware будет автоматически её подрезать и резюмировать
        SummarizationMiddleware(
            model="gpt-5",
            max_tokens_before_summary=1000,
        ),
    ],
)

# %%
result = agent_global.invoke({
    "messages": [
        {
            "role": "user",
            "content": """Начни обработку сделанных раннее summaries.
            Сделай итоговый отчет по всему проектy.
            """

        }
    ]
})

report = result["messages"][-1].content
print(report)
# Out:
# 1. Краткое резюме по проекту
# Проект фокусируется на стабилизации контуров логистики и выручки: корректность данных TM–SD (ЗНИ 272), устранение расхождений ВГО, доработка «Зеркало 2» по валютным счетам, перенос хранения номера вагона (ЗНИ 239), и внедрение распределения фактических транспортных затрат (TM→S4 с множественной контировкой). Параллельно идут работы по автоматизации EWM (автораспределение), согласованию регламентов и закрытию SD/JIRA-инцидентов. Критичны сроки к закрытию месяца; часть задач завязана на согласование ЗНИ и межблочную координацию.
#
# 2. Основные темы
# - ЗНИ 272 (TM–SD, корректность данных для выручки)
#   - Цель: передача даты коносамента и корректное заполнение даты перехода рисков; устранение типовых ошибок в заказах/поставках.
#   - Статус: подтверждена срочность; SD-спека по дате перехода рисков не финализирована; предварительный горизонт внедрения — не ранее середины марта, общий — 1–2 месяца.
#   - До релиза: ежедневный мониторинг новых заказов, ручное внесение фактической даты перехода рисков, полномочия/обучение логистов, чистка исторических кейсов по памятке (5 типов ошибок).
# - ВГО — расхождения
#   - Проблематика: разносимые валюты (RUB/UEU), курсовые разницы (особенно пары УК СГ–ВФК), влияние авансов, перенос позиций между месяцами.
#   - Подход: анализ нарастающим итогом, ориентация на проведение цепочки в RUB; утвержден регламент взаимодействия (МСФО → руководитель → ведущий бухгалтер с разбором причин).
#   - Сроки: ориентир устранения при ОК на ЗНИ — 5 марта; трудозатраты ~3 чел-дня.
# - «Зеркало 2 — валютные счета»
#   - Сделано: учтены правила двойного налогообложения; единая кодировка валют (EUR→UEU, USD→UUS); при одном ДРФ зеркало создается корректно.
#   - Нерешено: стабильность срабатывания (есть случаи «не срабатывает»), поддержка нескольких ДРФ в одном документе (нужен пакетный режим создания ПЗД), единые правила «1-в-1» по валютам (EUR–EUR vs EUR–UEU).
# - Разнесение фактических транспортных затрат (TM→S4)
#   - Цель: распределение стоимости перевозки по нескольким позициям сбыта и множественная контировка на несколько ОУР; изменение ТМ‑27.
#   - Архитектура: данные из ТМ уже приходят; PI расширять не требуется; вмешательство на этапе подготовки SES в обработчике входящего сообщения; возможен BADI/мэппинг заголовок/позиции.
#   - Статус: запрошены/уточняются оценки (ориентир P2P на ТМ‑27 — 5 ч/д); требуется реализация и тестирование распределения и множественной контировки.
# - ЗНИ 239 — номер вагона / «Паспорт качества»
#   - Изменение: перенос хранения номера вагона из LIKP‑TRAID в текст 1013 («Номер трансп. средства»).
#   - Зависимости: доработка формы MNF «Паспорт качества» и отчетности BW; информирование складов/логистики; для исторических поставок — ограничение (обнуление EWM и новая поставка).
#   - Связанные ограничения: после автораспределения из ТМ изменить номер вагона нельзя — будет снято с переносом соответствующих доработок.
# - Автоматическое распределение в EWM (SAPSP‑17498)
#   - Реализовано: автораспределение исходящих поставок с бумагой по авто (в т.ч. через ARKA) каждые 30 минут.
#   - Запрос на расширение: аналогичный режим для ЖД/контейнеров (покрытие вечер/выходные); пользователи ждут подтверждения даты запуска.
# - Регламенты/оргвопросы
#   - На согласовании регламенты ТМ (ведение НСИ, оперативное планирование перевозок); учтены дополнительные комментарии ИТ-линии, загрузка в СЭД до 01.03.
#   - Роли/ответственность по темам «Склад и Транспорт» распределены; встреч по ЗНИ‑282 и ГУ12 назначено много, содержательно — в основных потоках выше.
# - Инфраструктура и доступы
#   - Создание/расширение БП для склада (SEP500, завод 1311, S015) для прохождения ERP→TM.
#   - Доступы Лесосибирский ЛДК (SAPSP‑18265) — уточняются роль/матрица МПР, тикет переоткрывался.
#
# 3. Ключевые решения
# - ЗНИ 272:
#   - Подтвержден срочный приоритет; до релиза — ручной контроль даты перехода рисков и ежедневный мониторинг; закреплены ответственные и план очистки исторических данных.
# - ВГО:
#   - Принят подход проводить цепочки в RUB для устранения курсовых расхождений; формализован регламент работы с расхождениями и подключение аналитика при необходимости.
# - «Зеркало 2»:
#   - Зафиксирована кодировка валют (UEU/UUS) и логика налогов; принято к проработке — поддержка нескольких ДРФ и пакетное создание ПЗД; требуется унификация принципа «1-в‑1» для валют.
# - Разнесение фактических затрат:
#   - Решено реализовывать распределение в S4 на этапе SES без расширения PI; определить BADI/мэппинг и модификации ТМ‑27 для множественной контировки; получены предварительные оценки со стороны P2P.
# - ЗНИ 239:
#   - Принят перенос хранения номера вагона в текст 1013; согласована доработка MNF/BW; исторические документы — через workaround; обязательна коммуникация пользователям перед релизом.
# - EWM автораспределение:
#   - Подтверждена безрисковость текущего авто-режима для авто; решение — подготовить расширение на ЖД/контейнеры и убрать ограничение на изменение номера вагона после распределения.
# - Service Desk / JIRA:
#   - SAPSP‑18530 (Transporeon номер авто) — устранено.
#   - SAPSP‑17498 (автораспределение) — внедрено для авто, в планах расширение.
#   - SAPSP‑18554 (6100049111) — обработано; связанные корректировки по экспедитору выполнены.
#   - SAPSP‑18265 (доступы) — в работе, уточняется роль.
#
# 4. Проблемы и риски
# - Сроки и зависимости:
#   - ЗНИ 272: незавершенная SD-спека и неопределенность сроков (минимум — середина марта); риск сохранения ручных ошибок до релиза.
#   - ВГО: устранение завязано на ОК по ЗНИ и доступность аналитиков; критично к закрытию месяца.
# - Качество данных и методика:
#   - Валютные несоответствия (UEU vs RUB) и «1‑в‑1» по валютам в «Зеркало 2»; риск неверных проводок/ПЗД при нескольких ДРФ.
#   - Перенос позиций между месяцами и авансы в валюте усложняют сверку ВГО.
# - Технические:
#   - Реализация множественной контировки и распределения по позициям — нетривиальна, требует точной точки встраивания и тщательного тестирования.
#   - Ограничение EWM на изменение номера вагона после распределения до релиза связанных доработок.
# - Операционные:
#   - Неокончательно согласованные регламенты ТМ и роли доступа (Лесосибирский ЛДК) могут тормозить процессы.
#   - Невычищенные маршруты ВФК в ПУТ затрудняют сверку ТО.
#   - Не до конца ясны сроки запуска печати полного комплекта ГУ‑29 по контейнерам.
#
# 5. Повторяющиеся инциденты (объединённо)
# - ВГО: регулярные кейсы неверной валюты/курса и большие курсовые разницы (особенно УК СГ–ВФК); необходимость сторно/повторного проведения в RUB.
# - «Зеркало 2»: нестабильность срабатывания и отсутствие поддержки нескольких ДРФ; вопросы по валютным кодам и принципу «1‑в‑1».
# - EWM/Transporeon: эпизоды невыгрузки номера авто (ошибка сериализации очереди) — устранены; потребность расширения автораспределения на ЖД/контейнеры — повторяющийся запрос пользователей.
# - Доступы/роли: длительное уточнение роли для Лесосибирского ЛДК, переоткрытия тикета.
# - Методика ТО: сложности из‑за неактуальных маршрутов ВФК в ПУТ — регулярно всплывает при сверках.
#
# 6. Финальное резюме
# Проект продвинулся в унификации валют и налогов («Зеркало 2»), запуске автораспределения EWM для авто, подготовке архитектуры распределения транспортных затрат и переносе хранения номера вагона (ЗНИ 239). В краткосрочном фокусе:
# - ЗНИ 272: закрыть SD-спеку, зафиксировать план переноса в продуктив; до релиза — жесткий операционный контроль даты перехода рисков.
# - ВГО: получить ОК по ЗНИ, завершить анализ нарастающим итогом и устранение ключевых валютных кейсов до 5 марта.
# - «Зеркало 2»: реализовать поддержку нескольких ДРФ и утвердить правило «1‑в‑1» по валютам; провести проверку на примерах из логов.
# - Разнесение затрат: утвердить оценки, разработать BADI/мэппинг и изменения ТМ‑27; обеспечить тесты на множественных позициях/ОУР.
# - ЗНИ 239: финализировать MNF/BW и коммуникацию; выпустить с учетом ограничений по историческим документам.
# - EWM: расширить автораспределение на ЖД/контейнеры и снять ограничение по изменению номера вагона.
# - Организационно: закрыть вопросы по ролям (SAPSP‑18265), создать/расширить БП склада, загрузить отредактированные регламенты в СЭД и прояснить сроки по ГУ‑29.
#
# Выполнение этих шагов сняет основные блокеры к закрытию месяца и обеспечит целостность данных по выручке и затратам в контурах TM–S4/EWM.

# %%
from pipeline import EmailSummaryPipeline

pipeline = EmailSummaryPipeline(qv=qv, model="gpt-5")

# %%
pipeline.run_batch_processing("Segezha")
# Out:
# {'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n- Сохранено резюме Батч 1 (offset 0–49), период ~25–26.02.2021. Файл: summaries\\summary_batch_1.txt\n- Ключевые темы и действия:\n  - «Зеркало 2» (валютные счета): из ~20 док-ов создалось только 4 ПЗД на стороне ДЗК. Пример: ПЗД 5105630181 (БЕ 1650). В одном док-те несколько ДРФ; предложено отправлять по отдельности. Действия: прислать примеры/скриншоты; протестировать раздельную отправку ДРФ; подтвердить настройки.\n  - Расхождения по ВГО: ЗНИ 281 согласовано; план реализации ориентировочно 5 марта. Действия: подтвердить план-график и готовность к релизу.\n  - Корректность данных в SAP для расчёта выручки (ЗНИ 272): интеграция TM–SD, номер ЗНИ ещё не присвоен. Действия: присвоить/сообщить номер, согласовать сроки, получить вводные от финблока.\n  - SAPSP-17498 (автораспределение поставок по ж.д.): уведомления Jira SD. Действие: контролировать в SD-портале.\n  - Ж/д отгрузка, заведение ГУ12 (СЦБК): проведены рассылка/встреча с участием СЦБК и проектной команды.\n  - Календарь: подтверждения участия в «Разнесение фактических затрат логистики».\n  - Прочее: были тестовые письма без проектных деталей.\n- Основные участники: Ольга Тинтунен, Тимофей Кучкин, Елена Волкова, Анатолий Сафонов, Иван Жилин, Андрей Юдин, финблок (Шэлиговская/др.), команда BearingPoint.', additional_kwargs={}, response_metadata={}, id='64226e57-e3a9-4eb7-ad07-1605bf262197'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_TbqUCqsFbyoiN1P4G1Oo8WX0', 'function': {'arguments': '{"project_hint":"Segezha","offset":50,"batch_size":50}', 'name': 'search_project_emails_batch'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 16105, 'total_tokens': 16137, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-ClMZ1JLIdIOnkk3zk1XBp8OHyVhZu', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--70732491-b56d-4c88-ad2c-66c67f8cb205-0', tool_calls=[{'name': 'search_project_emails_batch', 'args': {'project_hint': 'Segezha', 'offset': 50, 'batch_size': 50}, 'id': 'call_TbqUCqsFbyoiN1P4G1Oo8WX0', 'type': 'tool_call'}], usage_metadata={'input_tokens': 16105, 'output_tokens': 32, 'total_tokens': 16137, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='{"project_hint": "Segezha", "offset": 50, "batch_size": 50, "batch_len": 50, "has_more": true, "batch": [{"subject": "RE: Корректность данных в SAP для расчета выручки (добавила повестку) ЗНИ 272", "snippet": "С уважением,\\nПавел Веселов\\n+7 (916) 993-7240\\nтел. +7 (499) 429-08-52 (доб. 10600)\\nмоб. +7 985 276-37-29\\nE-mail:Felikova_EV@segezha-group.com\\nПодписаться на новости компании можно здесь <http://segezha-group.com/subscription/>\\nМы с вами также в «ВКонтакте» <https://vk.com/segezhagroup>   Facebook <https://www.facebook.com/segezhagroup>   Instagram <https://www.instagram.com/segezhagroup/>\\nОфициальный сайт: www.segezha-group.com <http://www.segezha-group.com/>\\n………………………………………………………………………………………………..\\nПрежде, чем распечатать это письмо, подумайте об окружающей среде\\nЭто электронное письмо является ", "sent_at_utc": "2021-02-26 10:06:32", "thread_key": "корректность данных в sap для расчета выручки (добавила повестку) зни 272||alexey.ivanenko@bearingpoint.ru;andrey.kryukov@bearingpoint.ru;ivan.dondukov@bearingpoint.ru;petr.ostrik@bearingpoint.ru"}, {"subject": "Принято: Разнесение факти*еских затрат логистики", "snippet": "Принято: Разнесение факти*еских затрат логистики", "sent_at_utc": "2021-02-26 12:59:06", "thread_key": "принято: разнесение факти*еских затрат логистики||ce-sergey.grach@bearingpoint.ru;petr.ostrik@bearingpoint.ru"}, {"subject": "RE: Зеркало 2: мемо - для информации по валютным счетам", "snippet": "RE: Зеркало 2: мемо - для информации по валютным счетам\\nКогда в одном документе один ДРФ, зеркало создается, проверено )\\nА можно сделать, чтобы в одном документе с несколькими ДРФ создавалось зеркало?\\nПросто бывает в одном документе от пяти до десяти ДРФ и очень трудозатратно выходит…\\nС уважением,\\nОльга Тинтунен\\nСпециалист по бюджетированию и аналитике, Дирекция по логистике\\nООО «Управляющая компания «Сегежа Групп»\\nАдрес: 185035, г.Петрозаводск,\\nпр. Ленина, д.21 (каб. 441)\\nМоб.: +7 921 013-08-75\\nE-mail: tintunen_ov@segezha-group.com <mailto:tintunen_ov@segezha-group.com>\\nПодписаться на новости", "sent_at_utc": "2021-02-26 11:38:43", "thread_key": "зеркало 2: мемо - для информации по валютным счетам||petr.ostrik@bearingpoint.ru;timofey.kuchkin@bearingpoint.ru;tintunen_ov@segezha-group.com"}, {"subject": "RE: Корректность данных в SAP для расчета выручки (добавила повестку) ЗНИ 272", "snippet": "Официальный сайт: www.segezha-group.com <http://www.segezha-group.com/>\\n………………………………………………………………………………………………..\\nПрежде, чем распечатать это письмо, подумайте об окружающей среде\\nЭто электронное письмо является конфиденциальным. Если Вы его получили по ошибке, прошу удалить и сообщить отправителю.\\nС уважением,\\nАндрей Юдин\\nДиректор по логистике\\nООО «УК «Сегежа Групп»\\nМосква, Пресненская набережная, 10, Блок С\\nРаб.: +7(499)962-82-00 доб. 10444\\nМоб.: +7 915 082 11 83\\nE-mail: Yudin_AV@segezha-group.com <mailto:Yudin_AV@segezha-group.com>\\nПодписаться на новости компании можно здесь <http://segezha-gr", "sent_at_utc": "2021-02-26 10:06:32", "thread_key": "корректность данных в sap для расчета выручки (добавила повестку) зни 272||alexey.ivanenko@bearingpoint.ru;andrey.kryukov@bearingpoint.ru;ivan.dondukov@bearingpoint.ru;petr.ostrik@bearingpoint.ru"}, {"subject": "RE: Корректность данных в SAP для расчета выручки (добавила повестку) ЗНИ 272", "snippet": "Официальный сайт: www.segezha-group.com <http://www.segezha-group.com/>\\n………………………………………………………………………………………………..\\nПрежде, чем распечатать это письмо, подумайте об окружающей среде\\nЭто электронное письмо является конфиденциальным. Если Вы его получили по ошибке, прошу удалить и сообщить отправителю.\\nС уважением,\\nАндрей Юдин\\nДиректор по логистике\\nООО «УК «Сегежа Групп»\\nМосква, Пресненская набережная, 10, Блок С\\nРаб.: +7(499)962-82-00 доб. 10444\\nМоб.: +7 915 082 11 83\\nE-mail: Yudin_AV@segezha-group.com <mailto:Yudin_AV@segezha-group.com>\\nПодписаться на новости компании можно ...
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_Ud61bHZs8VGNQCRylFIOfYPS', 'function': {'arguments': '{"summary_text":"Батч 2 (offset 50–99)\\nПериод: 25–26.02.2021.\\nКлючевые темы и выводы:\\n- Зеркало 2 (мемо по валютным счетам): подтверждено, что зеркалирование успешно при одном ДРФ в документе; есть запрос реализовать зеркалирование для документов с несколькими ДРФ (5–10 в одном документе). Кучкин сообщил о фиксе двойного налогообложения и добавлении мэппинга валют EUR→UEU, USD→UUS; дополнительно уточняется требование, чтобы валюта передавалась 1-в-1 (обсуждение расхождений EUR vs UEU). Действия: согласовать единую схему кодов валют и доработать зеркалирование для многократных ДРФ.\\n- ЗНИ 272 (корректность данных для выручки, TM→SD): ЗНИ согласовано (передача даты коносамента и даты перехода рисков в исходящей поставке); необходимо озвучить клиенту плановый срок переноса в продуктив. Обсуждаются приоритет и формат (срочно для финблока). Действия: определить срок релиза и уведомить стейкхолдеров.\\n- Расхождения по ВГО / ЗНИ 281: обсуждение сроков и трудозатрат (оценка 3 чел.-дня), уточняется возможность успеть сторнировать/перепровести документы за 3 дня до закрытия месяца. Действия: согласовать трудозатраты, подтвердить план и дедлайн.\\n- SAPSP-17498 (авт. распределение поставок по ж.д.): уведомления SD, шаринг задачи с участниками (Широкина, Щукин, Острик, Хусаинов). Действия: мониторинг статуса.\\n- SAPSP-18554 (6100049111): задача в Jira помечена как «Готово». Действия: при необходимости принять в эксплуатацию.\\n- SAPSP-17588 (Замечание ОПЭ СЦБК №62): тикет назначен на Тимофея Кучкина. Действия: ожидание выполнения.\\n- Ж/Д ГУ12/ГУ-29 (СЦБК): запрошены сроки запуска печати полного комплекта ж.д. накладной ГУ-29 на контейнеры (ранее называлась дата 13/02). Действия: предоставить обновлённый план запуска.\\n- Календарь: подтверждения встреч по «Разнесение фактических затрат логистики».\\nОсновные участники: Ольга Тинтунен, Тимофей Кучкин, Алексей Иваненко, Андрей Юдин, Иван Жилин, Елена Волкова, Анатолий Сафонов, Елена Широкина, участники SAP Support/Jira.","batch_id":2}', 'name': 'save_summary'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 666, 'prompt_tokens': 31576, 'total_tokens': 32242, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 16128}}, 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-ClMZ3jpE9aePSiRMJjjpUjQXOZ0oe', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--43682d30-e79f-476c-a293-1aeccf180edf-0', tool_calls=[{'name': 'save_summary', 'args': {'summary_text': 'Батч 2 (offset 50–99)\nПериод: 25–26.02.2021.\nКлючевые темы и выводы:\n- Зеркало 2 (мемо по валютным счетам): подтверждено, что зеркалирование успешно при одном ДРФ в документе; есть запрос реализовать зеркалирование для документов с несколькими ДРФ (5–10 в одном документе). Кучкин сообщил о фиксе двойного налогообложения и добавлении мэппинга валют EUR→UEU, USD→UUS; дополнительно уточняется требование, чтобы валюта передавалась 1-в-1 (обсуждение расхождений EUR vs UEU). Действия: согласовать единую схему кодов валют и доработать зеркалирование для многократных ДРФ.\n- ЗНИ 272 (корректность данных для выручки, TM→SD): ЗНИ согласовано (передача даты коносамента и даты перехода рисков в исходящей поставке); необходимо озвучить клиенту плановый срок переноса в продуктив. Обсуждаются приоритет и формат (срочно для финблока). Действия: определить срок релиза и уведомить стейкхолдеров.\n- Расхождения по ВГО / ЗНИ 281: обсуждение сроков и трудозатрат (оценка 3 чел.-дня), уточняется возможность успеть сторнировать/перепровести документы за 3 дня до закрытия месяца. Действия: согласовать трудозатраты, подтвердить план и дедлайн.\n- SAPSP-17498 (авт. распределен ...
#   ToolMessage(content='saved_to=summaries\\summary_batch_2.txt', name='save_summary', id='8e5919bb-2a43-454c-919d-f967e17d55c2', tool_call_id='call_Ud61bHZs8VGNQCRylFIOfYPS'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_WzafJIJLcPtDlvFAp6KaPfUS', 'function': {'arguments': '{"project_hint":"Segezha","offset":100,"batch_size":50}', 'name': 'search_project_emails_batch'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 32264, 'total_tokens': 32296, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 32128}}, 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-ClMZCrN7Oun5U0bkAo3XtLfhUk2e3', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--35f32772-c291-4f8f-bb1e-c0fea1548bd1-0', tool_calls=[{'name': 'search_project_emails_batch', 'args': {'project_hint': 'Segezha', 'offset': 100, 'batch_size': 50}, 'id': 'call_WzafJIJLcPtDlvFAp6KaPfUS', 'type': 'tool_call'}], usage_metadata={'input_tokens': 32264, 'output_tokens': 32, 'total_tokens': 32296, 'input_token_details': {'audio': 0, 'cache_read': 32128}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='{"project_hint": "Segezha", "offset": 100, "batch_size": 50, "batch_len": 50, "has_more": true, "batch": [{"subject": "RE: расхождения по ВГО", "snippet": "Копия: Спесивова Ольга Владимировна <Spesivova_OV@segezha-group.com <mailto:Spesivova_OV@segezha-group.com> >; Окунева Екатерина Николаевна <okuneva_en@segezha-group.com <mailto:okuneva_en@segezha-group.com> >; \'Иван Корнев\' <ivan.kornev@sbs.expert <mailto:ivan.kornev@sbs.expert> >\\nТема: FW: расхождения по ВГО\\nДобрый день, коллеги!\\nИван, подключайтесь.\\nВсе пары 1 волны сверены монитором сверки.\\nОднако, даже в них есть расхождения.\\nВы говорили, что можно нарастающим итогом посмотреть-показывпйте как.\\nПотомучто много позиций переходящих в разные месяца, быстро нам не определить.\\nС уважением,\\nАна", "sent_at_utc": "2021-02-26 09:42:45", "thread_key": "расхождения по вго||Emelyanova_OA@segezha-group.com;Felikova_EV@segezha-group.com;Safonov_AY@segezha-group.com;ce-ivan.zhilin@bearingpoint.ru;elena.zvereva@bearingpoint.ru;petr.ostrik@bearingpoint.ru;volkova_ev@segezha-group.com"}, {"subject": "RE: расхождения по ВГО", "snippet": "Копия: Спесивова Ольга Владимировна <Spesivova_OV@segezha-group.com <mailto:Spesivova_OV@segezha-group.com> >; Окунева Екатерина Николаевна <okuneva_en@segezha-group.com <mailto:okuneva_en@segezha-group.com> >; \'Иван Корнев\' <ivan.kornev@sbs.expert <mailto:ivan.kornev@sbs.expert> >\\nТема: FW: расхождения по ВГО\\nДобрый день, коллеги!\\nИван, подключайтесь.\\nВсе пары 1 волны сверены монитором сверки.\\nОднако, даже в них есть расхождения.\\nВы говорили, что можно нарастающим итогом посмотреть-показывпйте как.\\nПотомучто много позиций переходящих в разные месяца, быстро нам не определить.\\nС уважением,\\nАна", "sent_at_utc": "2021-02-26 09:44:17", "thread_key": "расхождения по вго||Emelyanova_OA@segezha-group.com;Felikova_EV@segezha-group.com;Safonov_AY@segezha-group.com;ce-ivan.zhilin@bearingpoint.ru;elena.zvereva@bearingpoint.ru;petr.ostrik@bearingpoint.ru;volkova_ev@segezha-group.com"}, {"subject": "RE: расхождения по ВГО", "snippet": "Копия: Спесивова Ольга Владимировна <Spesivova_OV@segezha-group.com <mailto:Spesivova_OV@segezha-group.com> >; Окунева Екатерина Николаевна <okuneva_en@segezha-group.com <mailto:okuneva_en@segezha-group.com> >; \'Иван Корнев\' <ivan.kornev@sbs.expert <mailto:ivan.kornev@sbs.expert> >\\nТема: FW: расхождения по ВГО\\nДобрый день, коллеги!\\nИван, подключайтесь.\\nВсе пары 1 волны сверены монитором сверки.\\nОднако, даже в них есть расхождения.\\nВы говорили, что можно нарастающим итогом посмотреть-показывпйте как.\\nПотомучто много позиций переходящих в разные месяца, быстро нам не определить.\\nС уважением,\\nАна", "sent_at_utc": "2021-02-25 17:40:14", "thread_key": "расхождения по вго||Emelyanova_OA@segezha-group.com;Safonov_AY@segezha-group.com;ce-ivan.zhilin@bearingpoint.ru;elena.zvereva@bearingpoint.ru;petr.ostrik@bearingpoint.ru;volkova_ev@segezha-group.com"}, {"subject": "RE: расхождения по ВГО", "snippet": "Копия: Спесивова Ольга Владимировна <Spesivova_OV@segezha-group.com <mailto:Spesivova_OV@segezha-group.com> >; Окунева Екатерина Николаевна <okuneva_en@segezha-group.com <mailto:okuneva_en@segezha-group.com> >; \'Иван Корнев\' <ivan.kornev@sbs.expert <mailto:ivan.kornev@sbs.expert> >\\nТема: FW: расхождения по ВГО\\nДобрый день, коллеги!\\nИван, подключайтесь.\\nВсе пары 1 волны сверены монитором сверки.\\nОднако, даже в них есть расхождения.\\nВы говорили, что можно нарастающим итогом посмотреть-показывпйте как.\\nПотомучто много позиций переходящих в разные месяца, быстро нам не определить.\\nС уважением,\\nАна", "sent_at_utc": "2021-02-25 16:17:17", "thread_key": "расхождения по вго||Emelyanova_OA@segezha-group.com;Safonov_AY@segezha-group.com;ce-ivan.zhilin@bearingpoint.ru;elena.zvereva@bearingpoint.ru;petr.ostrik@bearingpoint.ru;volkova_ev@segezha-group.com"}, {"subject": "RE: расхождения по ВГО", "snippet": "Копия: Спесивова Ольга Владимировна <Spesivova_OV ...
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_Wae1FdPliqK4MbRTyvXuqEU4', 'function': {'arguments': '{"summary_text":"Батч 3 (offset 100–149)\\nПериод: 25–28.02.2021.\\nКлючевые темы и выводы:\\n- Расхождения по ВГО: продолжается обсуждение методики сверки (просмотр нарастающим итогом), сохраняются расхождения даже по парам 1-й волны. Отдельные вопросы по курсовым разницам между УК СГ и ВФК; затронуты проблемы разной валюты во входящих/исходящих документах и ошибочного проведения в UEU (счет 649, срочно). Уточнены трудозатраты (3 чел.-дня) и срок выполнения при согласовании ЗНИ — до 5 марта. Действия: согласовать ЗНИ, провести корректировки, продемонстрировать сверку «нарастающим итогом», урегулировать валютные несоответствия.\\n- Зеркало 2 (валютные счета): внедрен фикс двойного налогообложения и мэппинг валют EUR→UEU, USD→UUS; при этом заказчик настаивает на передаче валюты 1-в-1 (EUR=EUR), требуется прояснение различий EUR vs UEU. Действия: согласовать/исполнить единый справочник кодов валют и правила зеркалирования, особенно для кейса с несколькими ДРФ.\\n- ЗНИ 272 (TM→SD, дата коносамента/переход рисков): обсуждаются организационные шаги (контроли в сбытовых заказах, исправление данных, распределение ответственности по ДЗО) и сроки переноса в продуктив; подтверждена срочность для финблока. Действия: определить релизный план, инициировать ЗНИ на контроли в заказах, обеспечить временные ручные проверки.\\n- SD/Jira:\\n  • SAPSP-18530: не выгрузился номер авто из Transporeon (6100065014) — назначено на П. Острика.\\n  • SAPSP-18554 (6100049111): задача переведена в «Готово», запрос на корректировку экспедитора — Алсика.\\n  • SAPSP-18265: открыть доступ к поставкам Лесосибирского ЛДК — вопрос по настройке профиля, запрошено подтверждение.\\n- Регламенты/процессы ТМ: вынесены на согласование протокол и регламент оперативного планирования перевозок; дополнительные комментарии ИТ-линии (Щукин). Действия: пройти согласование до 01.03, учесть комментарии.\\n- «Еще раз про логистику»: инициатива по начислениям транспортных расходов (пошаговая схема, ограничения по АРКА), запрос на подготовку презентации. Действия: сверить подход, подготовить материал.\\n- Разнесение фактических транспортных затрат: рабочие обсуждения разнесения по позициям ТС и кейсам.\\n- Прочее: ссылки на материалы по «Зеркалу 2» в облаке BP; служебные письма HR/1С не по проектной повестке.\\nОсновные участники: Иван Жилин, Елена Волкова, Ольга Емельянова, Ирина Наливко, Тимофей Кучкин, Алексей Иваненко, Андрей Юдин, Алексей Щукин, Василий Анисимов, Айгуль Сафина, Наталия Пустовитова, др.","batch_id":3}', 'name': 'save_summary'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 797, 'prompt_tokens': 47897, 'total_tokens': 48694, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 32256}}, 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-ClMZFcgImsQ5NF0O7zjlZ190odDU8', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--43b1e226-f420-465e-a522-7c5e1427bb20-0', tool_calls=[{'name': 'save_summary', 'args': {'summary_text': 'Батч 3 (offset 100–149)\nПериод: 25–28.02.2021.\nКлючевые темы и выводы:\n- Расхождения по ВГО: продолжается обсуждение методики сверки (просмотр нарастающим итогом), сохраняются расхождения даже по парам 1-й волны. Отдельные вопросы по курсовым разницам между УК СГ и ВФК; затронуты проблемы разной валюты во входящих/исходящих документах и ошибочного проведения в UEU (счет 649, срочно). Уточнены трудозатраты (3 чел.-дня) и срок выполнения при согласовании ЗНИ — до 5 марта. Действия: согласовать ЗНИ, провести корректировки, продемонстрировать сверку «нарастающим итогом», урегулировать валютные несоответствия.\n- Зеркало 2 (валютные счета): внедрен фикс двойного нало ...
#   ToolMessage(content='saved_to=summaries\\summary_batch_3.txt', name='save_summary', id='1161f4f7-37a6-4adf-b12c-ae31ed2ea760', tool_call_id='call_Wae1FdPliqK4MbRTyvXuqEU4'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_cZoJUFyUMP6zxW7jRNe0zDjp', 'function': {'arguments': '{"project_hint":"Segezha","offset":150,"batch_size":50}', 'name': 'search_project_emails_batch'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 48716, 'total_tokens': 48748, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 48640}}, 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-ClMZRfKgQzJgdP26naPDqUtwv0moC', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--8e57d394-6d82-465f-8fa0-686b162c5a6b-0', tool_calls=[{'name': 'search_project_emails_batch', 'args': {'project_hint': 'Segezha', 'offset': 150, 'batch_size': 50}, 'id': 'call_cZoJUFyUMP6zxW7jRNe0zDjp', 'type': 'tool_call'}], usage_metadata={'input_tokens': 48716, 'output_tokens': 32, 'total_tokens': 48748, 'input_token_details': {'audio': 0, 'cache_read': 48640}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='{"project_hint": "Segezha", "offset": 150, "batch_size": 50, "batch_len": 50, "has_more": true, "batch": [{"subject": "RE: еще раз про логистику", "snippet": "RE: еще раз про логистику\\nКоллеги, добрый день\\nПо данному вопросу были какие-то дальнейшие действия или решения? Вопрос актуален и существенен с точки зрения отражения полноты затрат в периоде и корректного расчета выручки очищенной от транспорта.\\nС уважением,\\nВиталий Лопаткин\\nРуководитель направления по контроллингу\\nУправление по финансам и инвестициям\\nООО «УК «Сегежа групп»\\nтел. : +7 (499) 429-08-52, доб. 10428\\nмоб.: +7 (925) 006-80-25\\ne-mail: lopatkin_va@segezha-group.com <mailto:lopatkin_va@segezha-group.com>\\nРоссия, 123112, г. Москва,\\nПресненская наб. 10, Блок С, этаж 45\\nПодписаться на но", "sent_at_utc": "2021-02-28 16:51:43", "thread_key": "еще раз про логистику||alexey.ivanenko@bearingpoint.ru;ce-ivan.zhilin@bearingpoint.ru;ce-valentin.konev@bearingpoint.ru;elena.zvereva@bearingpoint.ru;gorbunova_ib@segezha-group.com;kate.katushenko@bearingpoint.ru;koteshov_dv@segezha-group.com;lopatkin_va@segezha-group.com;marchik_iv@segezha-group.com;petr.ostrik@bearingpoint.ru;tatiana.egorova@bearingpoint.ru;vershinina_ea@segezha-group.com;volkova_ev@segezha-group.com"}, {"subject": "RE: Обсуждение вопросов по ЗНИ-282 \\"ЗНИ_Изменение схемы учета вывозки сырья с филиалов Лесных ресурсов на СЦБК\\"", "snippet": "RE: Обсуждение вопросов по ЗНИ-282 \\"ЗНИ_Изменение схемы учета вывозки сырья с филиалов Лесных ресурсов на СЦБК\\"\\nЗНИ с номером\\n_____________________________________________\\nС Уважением,\\nХусаинов Дамир\\n-----Original Appointment-----\\nВо вложении ЗНИ:\\n<< File: ЗНИ_Изменение схемы учета вывозки сырья с филиалов Лесных ресурсов на СЦБК  2020-12-28.docx >>\\n.........................................................................................................................................\\nПрисоединиться к собранию Skype <https://meet.bearingpoint.ru/rasul.abdulin/OGH3UZSN>\\nПроблемы при присоединен", "sent_at_utc": "2021-02-26 05:54:14", "thread_key": "обсуждение вопросов по зни-282 \\"зни_изменение схемы учета вывозки сырья с филиалов лесных ресурсов на сцбк\\"||IMCEAEX-_o=ilp_ou=Exchange+20Administrative+20Group+20+28FYDIBOHF23SPDLT+29_cn=Recipients_cn=user128488d2@bearingpoint.ru;Khusainov_DS@segezha-group.com;Lytkin_AV@segezha-group.com;Safonov_AY@segezha-group.com;alexey.ivanenko@bearingpoint.ru;andrey.kryukov@bearingpoint.ru;dmitry.kubyshkin@bearingpoint.ru;oleg.nesterov@bearingpoint.ru;olga.alekseeva@bearingpoint.ru;petr.ostrik@bearingpoint.ru;rasul.abdulin@bearingpoint.ru"}, {"subject": "[JIRA] (SAPSP-18265) Открыть доступ к поставкам Лесосибирского ЛДК", "snippet": "[JIRA] (SAPSP-18265) Открыть доступ к поставкам Лесосибирского ЛДК\\n<https://www.gravatar.com/avatar/bc1100ceff6b2e594b77863b7fb3a79f?d=mm&s=48> \\tШэлиговска Елена Александровна <http://192.168.210.55:8080/secure/ViewProfile.jspa?name=Szeligowska_EA%40segezha-group.com>  прокомментировал(а)  SAPSP-18265 <http://192.168.210.55:8080/browse/SAPSP-18265>\\nОтвет: Открыть доступ к поставкам Лесосибирского ЛДК <http://192.168.210.55:8080/browse/SAPSP-18265>\\nколлеги, как будет звучать роль?\\n<http://192.168.210.55:8080/browse/SAPSP-18265#add-comment> \\tДобавить комментарий <http://192.168.210.55:8080/brows", "sent_at_utc": "2021-02-26 05:35:02", "thread_key": "[jira] (sapsp-18265) открыть доступ к поставкам лесосибирского лдк||petr.ostrik@bearingpoint.ru;sap_support@segezha-group.com"}, {"subject": "не выгрузился из Транспореона номер авто 6100065014", "snippet": "не выгрузился из Транспореона номер авто 6100065014\\nДобрый день.\\nне выгрузился из Транспореона номер авто\\n\u200b\\nПустовитова Наталия,\\nРуководитель проектов по автомобильным перевозкам\\nДирекция по логистике\\nООО «УК «Сегежа групп»\\nТел. +7 (499) 962-82-00, доб.10477\\nМоб. +7-915-018-44-60\\nPustovitova_ns@segezha-group.com\u200b", "sent_at_utc": "2021-02-26 10 ...
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_bH9dcqc99RlE4RR0H40SUZHM', 'function': {'arguments': '{"summary_text":"Батч 4 (offset 150–199)\\nПериод: 25–28.02.2021.\\nКлючевые темы и выводы:\\n- «Еще раз про логистику»: поднята важность решения по начислениям транспортных расходов для корректной выручки; запрос статуса и дальнейших действий. Действия: подтвердить выбранный подход и план внедрения.\\n- ЗНИ-282 (вывозка сырья на СЦБК): обсуждение с указанием, что у ЗНИ есть номер; конференция для вопросов. Действия: продолжить согласование/реализацию.\\n- Доступ к поставкам Лесосибирского ЛДК (SAPSP-18265): уточняется формулировка роли в матрице МПР; тикет переведен «в работе/переоткрыт». Действия: определить и указать корректную роль, закрыть запрос.\\n- Проблема интеграции Transporeon (SAPSP-18530): не выгрузился номер авто 6100065014; выявлена ошибка сериализации очереди XBQRXI_SERIALIZE6727; тикет решен (статус «Готово»), часть данных вводилась вручную. Действия: проверить стабильность очереди и сценария выгрузки.\\n- Регламенты ТМ: обсуждение комментариев и исправлений; материалы загружены, просьба внести правки и загрузить в СЭД, подтверждено, что правки внесены. Действия: завершить согласование до 01.03.\\n- ЗНИ 272 (TM→SD): сроки — «не раньше середины марта», наполнение ЗНИ недостаточно и не согласовано основным заказчиком; ЗНИ нужно прежде всего логистам (исключить двойной ввод дат). Действия: доработать спецификацию (инкотермс, сценарии), согласовать, спланировать релиз.\\n- ЗНИ 239 (изменение номера вагона): изменение источника хранения номера вагона (LIKP-TRAID → текст 1013 «Номер трансп. средства»); требуется документ постановки; тестирование формы MNF «Паспорт качества» продолжается; ограничение — исторические исходящие поставки до переноса. Действия: предоставить постановочный документ, завершить тест и релиз.\\n- «Зеркало 2»: продолжается согласование кодов валют (EUR vs UEU), ссылки на материалы; также указаны корректные МВП/МВЗ для ВФК в табличной части. Действия: финализировать справочники/мэппинг валют и настройки зеркалирования.\\n- Создание БП для склада S015 (завод 1311, SEP500): запрос на создание и расширение BP, добавление альтернативного идентификатора, причина — документы из ERP не попадают в TM. Действия: завести/расширить BP и проверить поток документов.\\n- Сверка ТО/маршрутов ВФК: замечены маршруты ВФК в ПУТ, что осложняет сверку; запрошена информация, кто общался с Никоноровым (неизвестно). Действия: определить ответственных и очистить маршруты.\\n- Разнесение фактических транспортных затрат: серия обсуждений — необходимость множественной контировки на несколько ОУР (оценка: 5 ч/д на постановку/тест/поддержку; запрос оценки разработки ТМ-27), технические детали обработки входящего сообщения «TransportationOrderSUITEInvoicingPreparationRequest_In» (классы и методы), распределение суммы по позициям заказа (пропорции), проверка необходимости расширения PI (не требуется). Действия: оценить и реализовать доработки ТМ-27 и логику распределения.\\n- Прочее: служебные письма (расчетный листок), запрос актуализации приложения 1 к ТЗ TM.021, HR-уведомления.\\nОсновные участники: Виталий Лопаткин, Дамир Хусаинов, Елена Шэлиговская, Василий Росляков, Наталия Пустовитова, Айгуль Сафина, Елена Рогожникова, Алексей Щукин, Олег Нестеров, Иван Дондуков, Алексей Иваненко, Михаил Григорьев, Петр Острик, др.","batch_id":4}', 'name': 'save_summary'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 994, 'prompt_tokens': 64436, 'total_tokens': 65430, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 48640}}, 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-ClMZUDsGOUyLR5PwVHTT6SlBHdMqo', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc ...
#   ToolMessage(content='saved_to=summaries\\summary_batch_4.txt', name='save_summary', id='2a3fbe67-d72d-406f-baaa-b47e512f703f', tool_call_id='call_bH9dcqc99RlE4RR0H40SUZHM'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_UyA8mlCjnr66MGLTXpijOAdZ', 'function': {'arguments': '{"project_hint":"Segezha","offset":200,"batch_size":50}', 'name': 'search_project_emails_batch'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 65452, 'total_tokens': 65484, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 65408}}, 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-ClMZjaUUMKOnVrfIfvnhB68vQmEMn', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--3ac97cad-6ee9-4001-aa5a-181bf2c4ee42-0', tool_calls=[{'name': 'search_project_emails_batch', 'args': {'project_hint': 'Segezha', 'offset': 200, 'batch_size': 50}, 'id': 'call_UyA8mlCjnr66MGLTXpijOAdZ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 65452, 'output_tokens': 32, 'total_tokens': 65484, 'input_token_details': {'audio': 0, 'cache_read': 65408}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='{"project_hint": "Segezha", "offset": 200, "batch_size": 50, "batch_len": 50, "has_more": true, "batch": [{"subject": "RE: Сверка ТО", "snippet": "RE: Сверка ТО\\nКоллеги маршруты ВФК из ПУТ не убраны.\\nСверку очень сложно делать…\\n4. Далее необходимо выбрать Массовое ведение ТО и выбрать жёлтую стрелку напротив Начального местоположения\\n5. Заходим в меню выбора копируем из буфера начальные местоположения, через кнопку, CTRL C + CTRL V ограничена набором полей, лучше через кнопку.\\n6. То же самое делаем для конечных местоположений.\\n7. Далее нажимаем просмотреть , получаем таблицу с нашими ТО.\\nСтавим фильтр по начальной дате, любой либо вверх , либо вниз\\nВыгружаем в электронную таблицу.\\n8. Далее делаем сцепку и ВПР , как и делали со стандартны", "sent_at_utc": "2021-02-25 17:53:51", "thread_key": "сверка то||nikonorov_kv@segezha-group.com;oleg.nesterov@bearingpoint.ru;petr.ostrik@bearingpoint.ru"}, {"subject": "Re: Разнесение фактических транспортных затрат", "snippet": "Re: Разнесение фактических транспортных затрат\\nДобрый день!\\nПравильно я понял, что все данные уже приходят из ТМ и нужно только мэппинг для сбытового заказа подправить?\\nТам есть BADI для мэппинга в структуры заголовка/позиций.\\nС уважением, Овчинников Сергей.\\nТел. +7 902 838 50 68\\n________________________________\\nОт: Materkov Artem(CE)\\nОтправлено: 26 февраля 2021 г. 12:41\\nКому: Fedoseev Alexey(CE); Ostrik Petr; Ovchinnikov Sergey(CE)\\nКопия: Zvereva Elena; Grach Sergey(CE); Konev Valentin(CE); Kazaryan Levon; Katushenko Kate; Strelkov Ivan(CE); Pinkhasov Dmitriy(CE)\\nТема: RE: Разнесение фактичес", "sent_at_utc": "2021-02-26 10:27:05", "thread_key": "разнесение фактических транспортных затрат||ce-Alexey.Fedoseev@bearingpoint.ru;ce-artem.materkov@bearingpoint.ru;ce-dmitriy.pinkhasov@bearingpoint.ru;ce-ivan.strelkov@bearingpoint.ru;ce-sergey.grach@bearingpoint.ru;ce-sergey.ovchinnikov@bearingpoint.ru;ce-valentin.konev@bearingpoint.ru;elena.zvereva@bearingpoint.ru;kate.katushenko@bearingpoint.ru;levon.kazaryan@bearingpoint.ru;petr.ostrik@bearingpoint.ru"}, {"subject": "RE: расхождения по ВГО", "snippet": "E-mail: Emelyanova_OA@segezha-group.com <mailto:Emelyanova_OA@segezha-group.com>\\nсайт: www.segezha-group.com <http://www.segezha-group.com/>\\n2.\\tСвязывание по целевой, не обработанные и не связанные счета по перевыставляемым услугам логистики – вопрос по связанным документам из-за разных валют во входящей и исходящем + ответ\\n3.\\tСчет 649, неверная сумма прихода – СРОЧНО!! – первый счет, который из-за проведения в базе в UEU ушел в оплату не по тому курсу. По вопросу с переплатой предложили чтобы Контрагент сделала возврат. Но для проведения возврата необходимо сформировать акт сверки (вопрос по ", "sent_at_utc": "2021-02-25 17:36:19", "thread_key": "расхождения по вго||Emelyanova_OA@segezha-group.com;Safonov_AY@segezha-group.com;ce-ivan.zhilin@bearingpoint.ru;elena.zvereva@bearingpoint.ru;petr.ostrik@bearingpoint.ru;volkova_ev@segezha-group.com"}, {"subject": "SAPSP-17498 автоматическое распределение поставок по ж.д.", "snippet": "SAPSP-17498 автоматическое распределение поставок по ж.д.\\n—-—-—-—\\nReply above this line.\\nshirokina_ee@segezha-group.com commented:\\nДа сделать\\nС уважением,\\nШирокина Елена Евгеньевна\\nНачальник отдела логистики\\nАО \\"Сегежский ЦБК\\"\\nтел. 8-81431-3-40-33\\nмоб:8-911-667-85-10\\nshirokina_ee@segezha-group.com <mailto:shirokina_ee@segezha-group.com>\\n<http://192.168.210.55:8080/servicedesk/customershim/secure/attachment/54503/54503_image001.jpg?fromIssue=31091>\\n________________________________\\nshirokina_ee@segezha-group.com commented:\\nСообщите тогда нам с какого дня автоматическое распределение будет работа", "sent_at_utc": "2021-02-26 13:40:00", "thread_key": "sapsp-17498 автоматическое распределение поставок по ж.д.||petr.ostrik@bearingpoint.ru;sap_support@segezha-group.com"}, {"subject": "RE: ЗНИ 239 Изменение номера вагона", "snippet": "RE: ЗНИ 239 Из ...
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_UpNpS1zbO9YU8sD6ZWbJBFcS', 'function': {'arguments': '{"summary_text":"Батч 5 (offset 200–249)\\nПериод: 25–26.02.2021.\\nКлючевые темы и выводы:\\n- Разнесение фактических транспортных затрат: техническая проработка — все данные приходят из ТМ, требуется корректный мэппинг в структуры SD; возможна точка расширения через BADI. Обсуждена точка модификации на этапе создания ведомости (SES) в обработке сообщения TransportationOrderSUITEInvoicingPreparationRequest_In (классы CL_TCM_*). Действия: определить BADI/точку встраивания, оценить и реализовать (включая множественную контировку и распределение по позициям заказа).\\n- Сверка ТО: проблемы из-за неубранных маршрутов ВФК из ПУТ; описаны шаги выгрузки ТО и сверки. Действия: удалить маршруты ВФК из ПУТ, продолжить сверку.\\n- SAPSP-17498 (автораспределение ЖД-поставок в EWM): запрос на включение, подтверждение «сделать», выполнение — с 26.02 17:26 МСК автораспределение для бумаги работает каждые 30 минут; предложение добавить автораспределение и для ЖД-отгрузок. Действия: подтвердить расширение на ЖД и мониторить.\\n- Проблемы Transporeon (SAPSP-18530): не выгрузился номер авто 6100065014; очередь XBQRXI_SERIALIZE6727 зависла по ошибке сериализации, затем тикет закрыт как «Готово». Пользователь временно внес данные вручную; в системе номер присутствует. Действия: проверить устойчивость интеграции и очередей.\\n- ЗНИ 239 (номер вагона): меняется источник хранения (LIKP-TRAID → текст 1013); требуется синхронизация с BW и информирование складов/логистов; идёт тест формы MNF «Паспорт качества», план запрошен; ограничение — для исторических исходящих поставок правка по старой схеме (EWM обнуление/новая поставка). Действия: завершить совместный тест с BW, согласовать перенос в продуктив, провести информ-встречу.\\n- ЗНИ 282 (вывозка сырья на СЦБК): подтверждено согласование ЗНИ; необходимость регулярных встреч по реализации. Действия: назначить еженедельные статусы, прислать документ с номером.\\n- ЗНИ 272 (TM→SD, выручка): зафиксированы орг. меры — мониторинг плановой/фактической дат перехода рисков, предоставление полномочий логистам, обучение; приложен файл «Перечень типовых ошибок МСФО15». Действия: продолжить внедрение процедур, готовить релиз ЗНИ.\\n- ВГО: определён регламент взаимодействия по расхождениям (канал через Спесивову → ведущим бухгалтерам → анализ/ответ). Также обсуждается перенос рублёвого сальдо в валютное и причины различий (реализации УК в рублях vs приход ВФК в валюте). Действия: назначить встречу по переносу сальдо, подключить Елену Краишкину, получить комментарий логистов.\\n- Прочее: HR-письмо об учёте рабочего времени.\\nОсновные участники: Артём Матерков, Алексей Федосеев, Сергей Овчинников, Олег Нестеров, Пётр Острик, Елена Широкина, Андрей Шарманов, Наталия Пустовитова, Айгуль Сафина, Михаил Григорьев, Алексей Иваненко, Анастасия Меньшикова, Ольга Спесивова и др.","batch_id":5}', 'name': 'save_summary'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 885, 'prompt_tokens': 81471, 'total_tokens': 82356, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 65408}}, 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-ClMZmqQMrjJFAYJppx9qHVXddyu7j', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--939cd518-04f6-407e-b1ff-d7e8d0c94881-0', tool_calls=[{'name': 'save_summary', 'args': {'summary_text': 'Батч 5 (offset 200–249)\nПериод: 25–26.02.2021.\nКлючевые темы и выводы:\n- Разнесение фактических транспортных затрат: техническая проработка — все данные приходят из ТМ, требуется корректный мэппинг в структуры SD; возможна точка расширения через BADI. Обсуждена точка модификации на этапе создания ведомости (SES) в обработке сообщения  ...
#   ToolMessage(content='saved_to=summaries\\summary_batch_5.txt', name='save_summary', id='4541745a-4731-4b2a-b056-4396a55fff75', tool_call_id='call_UpNpS1zbO9YU8sD6ZWbJBFcS'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_GaXU6qzQdhCAqqeqdb0cE0iO', 'function': {'arguments': '{"project_hint":"Segezha","offset":250,"batch_size":50}', 'name': 'search_project_emails_batch'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 82382, 'total_tokens': 82414, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-ClMa3dLmT5MjYKGGY2OSTnEpvJxAX', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--ec165502-f44f-4617-810d-c3876d821d03-0', tool_calls=[{'name': 'search_project_emails_batch', 'args': {'project_hint': 'Segezha', 'offset': 250, 'batch_size': 50}, 'id': 'call_GaXU6qzQdhCAqqeqdb0cE0iO', 'type': 'tool_call'}], usage_metadata={'input_tokens': 82382, 'output_tokens': 32, 'total_tokens': 82414, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='{"project_hint": "Segezha", "offset": 250, "batch_size": 50, "batch_len": 28, "has_more": false, "batch": [{"subject": "RE: расхождения по ВГО", "snippet": "Это электронное письмо является конфиденциальным. Если Вы его получили по ошибке, прошу удалить и сообщить отправителю.\\n8-919-108-81-10\\nВ ноябре Анастасия подняла этот вопрос, что так некорректно, и в начале декабря консультанты САП нам предложили другой вариант проведения документов, где вся цепочка документов уже проходит в рублях.\\nДля примера, отражение документов до 30.11:\\nВыставляет счет 177404М от 21.09.2020 - резидент в рублях на сумму 245 584,90 р., ставка по перевозке 2750 eur (указана в заявке)\\nЦепочка соответствующих документов:\\n21.09.2020\\n177404М\\n5100001103\\n21.09.2020\\n5700005384\\n51", "sent_at_utc": "2021-02-26 09:42:45", "thread_key": "расхождения по вго||Emelyanova_OA@segezha-group.com;Felikova_EV@segezha-group.com;Safonov_AY@segezha-group.com;ce-ivan.zhilin@bearingpoint.ru;elena.zvereva@bearingpoint.ru;petr.ostrik@bearingpoint.ru;volkova_ev@segezha-group.com"}, {"subject": "RE: расхождения по ВГО", "snippet": "Это электронное письмо является конфиденциальным. Если Вы его получили по ошибке, прошу удалить и сообщить отправителю.\\n8-919-108-81-10\\nВ ноябре Анастасия подняла этот вопрос, что так некорректно, и в начале декабря консультанты САП нам предложили другой вариант проведения документов, где вся цепочка документов уже проходит в рублях.\\nДля примера, отражение документов до 30.11:\\nВыставляет счет 177404М от 21.09.2020 - резидент в рублях на сумму 245 584,90 р., ставка по перевозке 2750 eur (указана в заявке)\\nЦепочка соответствующих документов:\\n21.09.2020\\n177404М\\n5100001103\\n21.09.2020\\n5700005384\\n51", "sent_at_utc": "2021-02-25 17:36:19", "thread_key": "расхождения по вго||Emelyanova_OA@segezha-group.com;Safonov_AY@segezha-group.com;ce-ivan.zhilin@bearingpoint.ru;elena.zvereva@bearingpoint.ru;petr.ostrik@bearingpoint.ru;volkova_ev@segezha-group.com"}, {"subject": "SAPSP-17498 автоматическое распределение поставок по ж.д.", "snippet": "SAPSP-17498 автоматическое распределение поставок по ж.д.\\n—-—-—-—\\nReply above this line.\\nШарманов Андрей commented:\\nТехнически рисков при автоматическом распределении исходящих поставок в EWM нет.\\nУ ТМ после распределения поставки в EWM на текущий момент нет возможности изменить номер вагона в поставке.\\nДанное ограничение будет снято после переноса всех разработок в рамках соответствующего ЗнИ.\\nView request <http://192.168.210.55:8080/servicedesk/customer/portal/2/SAPSP-17498?sda_source=notification-email>  · Turn off this request\'s notifications <http://192.168.210.55:8080/servicedesk/custome", "sent_at_utc": "2021-02-26 13:28:00", "thread_key": "sapsp-17498 автоматическое распределение поставок по ж.д.||petr.ostrik@bearingpoint.ru;sap_support@segezha-group.com"}, {"subject": "Онлайн лекция \\"Физиология в спорте, пульсовые зоны и зоны мощности\\" 5 марта", "snippet": "На лекции будут рассмотрены темы:\\n*       Физиология в спорте.\\n*       Пульсовые зоны и их влияние на развитие сердечно-сосудистой системы при занятиях физической активностью. Понятия МПК (максимальное потребление кислорода), ПАНО (порог анаэробного обмена), аэробное и анаэробное энергообеспечение организма. Зоны мощности и их сочетание с пульсовыми зонами.\\n*       Тренированное и нетренированное сердце бегуна. Отличие и возможные проблемы.\\n*       Ответы на вопросы.\\nЛекция рассчитана как на регулярно занимающихся спортом сотрудников, так и на новичков.\\nДля записи на лекцию необходимо заполнит", "sent_at_utc": "2021-02-26 06:46:30", "thread_key": "онлайн лекция \\"физиология в спорте, пульсовые зоны и зоны мощности\\" 5 марта||BeRuStaff@bearingpoint.ru;HR@bearingpoint.ru"}, {"subject": "Онлайн лекция \\"Физиология в спорте, пульсовые зоны и зоны мощности\\" 5 марта", "snippet": "Онлайн лекция \\"Физиология в спорте, пульсовые зоны и зоны мощности\\" 5 марта\\nЭто письмо  ...
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9xW2RQSQBqCtRD1trUid6HqS', 'function': {'arguments': '{"summary_text":"Батч 6 (offset 250–279)\\nПериод: 25–26.02.2021.\\nКлючевые темы и выводы:\\n- ВГО: продолжается обсуждение причин расхождений и примеров цепочек документов до/после изменения схемы (рубли vs UEU), без новых решений.\\n- ЗНИ 272 (TM→SD, корректность выручки): сформулирован план работ и оперативного мониторинга — анализ исторических заказов и их исправление, ежедневная аналитика по новым заказам, принудительное исправление ошибок ответственными, контроль плановой/фактической дат перехода рисков, наделение логистов правами и обучение. Приложен файл «Перечень типовых ошибок МСФО15». Действия: выполнять план, форсировать ЗНИ TM-SD, назначить ответственного за контроль.\\n- Создание БП для склада S015 (завод 1311): предоставлены реквизиты контрагента (8000000580) для создания/расширения Business Partner; цель — восстановить поток документов ERP→TM. Действия: завести/расширить BP и проверить интеграцию.\\n- SAPSP-17498 (автораспределение поставок): подтверждено отсутствие технических рисков для авто-распределения исходящих поставок в EWM; уточнены ограничения — до переноса связанных ЗНИ нельзя менять номер вагона в поставке после распределения. Также запрошено расширение авто-распределения на вагоны/контейнеры, приведены пояснения по текущей работе на СЦБК (каждые 30 мин). Действия: оценить расширение для ЖД, отслеживать ограничения до релиза ЗНИ.\\n- Прочее: корпоративные уведомления (HR, спорт), не проектные письма.\\nОсновные участники: Алексей Иваненко, Павел Веселов, Андрей Шарманов, Елена Широкина, Олег Нестеров, Семен Облезин, Петр Острик, др.","batch_id":6}', 'name': 'save_summary'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 482, 'prompt_tokens': 74654, 'total_tokens': 75136, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-ClMa8O2EB6tDHhOxBzj9KVrRQKqBk', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--f57eaa1b-ab37-4442-8563-cd66da673224-0', tool_calls=[{'name': 'save_summary', 'args': {'summary_text': 'Батч 6 (offset 250–279)\nПериод: 25–26.02.2021.\nКлючевые темы и выводы:\n- ВГО: продолжается обсуждение причин расхождений и примеров цепочек документов до/после изменения схемы (рубли vs UEU), без новых решений.\n- ЗНИ 272 (TM→SD, корректность выручки): сформулирован план работ и оперативного мониторинга — анализ исторических заказов и их исправление, ежедневная аналитика по новым заказам, принудительное исправление ошибок ответственными, контроль плановой/фактической дат перехода рисков, наделение логистов правами и обучение. Приложен файл «Перечень типовых ошибок МСФО15». Действия: выполнять план, форсировать ЗНИ TM-SD, назначить ответственного за контроль.\n- Создание БП для склада S015 (завод 1311): предоставлены реквизиты контрагента (8000000580) для создания/расширения Business Partner; цель — восстановить поток документов ERP→TM. Действия: завести/расширить BP и проверить интеграцию.\n- SAPSP-17498 (автораспределение поставок): подтверждено отсутствие технических рисков для авто-распределения исходящих поставок в EWM; уточнены ограничения — до переноса связанных ЗНИ нельзя менять номер вагона в поставке после распределения. Также запрошено расширение авто-распределения на вагоны/контейнеры, приведены пояснения по текущей работе на СЦБК (каждые 30 мин). Действия: оценить расширение для ЖД, отслеживать ограничения до релиза ЗНИ.\n- Прочее: корпоративные уведомления (HR, спорт), не проектные письма.\nОсновные участники: Алексей Иваненко, Павел Веселов, Андрей Шарманов, Елена Широкина, Олег Нестеров, Семен Облезин, Петр Острик, др.', 'batch_id': 6}, 'id': ' ...
#   ToolMessage(content='saved_to=summaries\\summary_batch_6.txt', name='save_summary', id='9996d4b0-9a62-4b39-a3e5-3d10734b580c', tool_call_id='call_9xW2RQSQBqCtRD1trUid6HqS'),
#   AIMessage(content='Все батчи обработаны', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 75036, 'total_tokens': 75044, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-ClMaVwqSF7liZJX6SaMEkMUXGUrUA', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--b84c8d9b-91a1-4659-9ebc-d611ebcad564-0', usage_metadata={'input_tokens': 75036, 'output_tokens': 8, 'total_tokens': 75044, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
final = pipeline.run_global_summary("Segezha")
print(final["messages"][-1].content)
# Out:
# 1. Краткое резюме по проекту
# Проект «Segezha» в отчетный период (25–28.02.2021) сосредоточен на стабилизации контура логистика–сбыт–финансы: корректность выручки по МСФО 15 (TM→SD, ЗНИ 272), сверка ВГО (ЗНИ 281), доработка «Зеркала 2» (валютные счета и многократные ДРФ), автоматизация распределения в EWM (SAPSP-17498), железнодорожные сценарии (ГУ-12/ГУ-29, ЗНИ 239), регламенты ТМ и разнесение фактических транспортных затрат. Достигнут ряд технических результатов (фикс двойного налогообложения, запуск автораспределения для бумаги, закрытие инцидента Transporeon), при этом ключевые ЗНИ находятся в согласовании/реализации и требуют синхронизации по срокам и спецификациям.
#
# 2. Основные темы
# - Корректность данных для выручки (ЗНИ 272, TM→SD): передача даты коносамента и даты перехода рисков, запуск оперативного мониторинга ошибок, план переноса в продуктив (ориентир — середина марта при доработке спецификации).
# - Сверка ВГО (ЗНИ 281): методика «нарастающим итогом», урегулирование курсовых и валютных расхождений (рубль vs UEU), дедлайны к закрытию месяца.
# - «Зеркало 2» (валютные счета): поддержка документов с несколькими ДРФ, единая политика валютных кодов (спор EUR vs UEU при требовании 1:1), устранение исторических перекосов (сч. 649).
# - Разнесение фактических транспортных затрат: мэппинг данных из ТМ в SD, точки встраивания (BADI), множественная контировка на несколько ОУР, распределение суммы по позициям заказа (оценка доработок ТМ-27).
# - EWM автораспределение (SAPSP-17498): включено для бумаги каждые 30 минут; обсуждается расширение на ЖД-отгрузки; ограничения до релиза ЗНИ 239 (нельзя менять номер вагона после распределения).
# - ЖД документы и данные: запуск печати полного комплекта ГУ-29; изменение источника хранения номера вагона (ЗНИ 239, LIKP-TRAID → текст 1013), синхронизация с BW, ограничения по историческим поставкам.
# - Регламенты ТМ: финализация протокола и регламента оперативного планирования перевозок, загрузка в СЭД и согласование до 01.03.
# - Интеграции и мастер-данные: инцидент Transporeon (невыгрузка номера авто), доступ к поставкам Лесосибирского ЛДК (SAPSP-18265), создание/расширение BP для склада S015 для восстановления потока ERP→TM.
#
# 3. Ключевые решения
# - Реализован фикс двойного налогообложения в «Зеркале 2» и мэппинг EUR→UEU, USD→UUS; принято к проработке требование передачи валюты 1:1 (финализация справочника валют в работе).
# - ЗНИ 272 согласован по сути (даты коносамента/перехода рисков); запущены организационные контроли и ежедневная аналитика; целевой перенос — не ранее середины марта, требуется доработка спецификации и согласование ключевым заказчиком.
# - ЗНИ 281: трудозатраты оценены (3 ч/д), ориентир выполнения — до 5 марта при своевременном согласовании.
# - SAPSP-17498: автораспределение исходящих поставок для бумаги включено (с 26.02, каждые 30 минут); принято к оценке расширение на ЖД.
# - SAPSP-18530 (Transporeon): инцидент закрыт («Готово»), использован разовый ручной ввод; требуется мониторинг устойчивости очередей.
# - ЗНИ 282 (вывозка сырья на СЦБК): согласовано, выбран режим регулярных статусов по реализации.
# - ЗНИ 239 (номер вагона): подтверждено изменение источника хранения; ведется совместный тест с BW; зафиксированы ограничения для исторических поставок; требуется постановочный документ перед релизом.
# - Регламенты ТМ: правки учтены, материалы готовы к загрузке в СЭД; дедлайн согласования — 01.03.
# - SAPSP-17498/EWM: подтверждено отсутствие техрисков для автораспределения исходящих поставок; отмечены ограничения по изменению номера вагона до релиза ЗНИ 239.
#
# 4. Проблемы и риски
# - Валютные несоответствия (EUR vs UEU) и связанные ошибки проводок/ВГО; риск неверной выручки и расхождений по счетам (в т.ч. 649).
# - «Зеркало 2» не обрабатывает документы с несколькими ДРФ — неполнота зеркалирования.
# - ЗНИ 272: неполная спецификация и несогласованность с основным заказчиком — риск срыва релиза и продолжения двойного ввода дат (несоответствие МСФО 15).
# - Узкие окна перед закрытием месяца: необходимость сторнировать/перепровести документы за 3 дня до закрытия — риск неуспевания корректировок по ВГО.
# - Интеграция Transporeon: нестабильность очереди XBQRXI_SERIALIZE6727 — риск потери данных и ручных вмешательств.
# - Ограничения EWM: до релиза ЗНИ 239 запрещено менять номер вагона после распределения — операционные риски при корректировках отгрузок.
# - Мастер-данные и доступы: отсутствие/задержка в создании BP S015 и корректного профиля доступа ЛДК — блокировка потоков документов.
# - Неопределенность по запуску печати ГУ-29 — риск срыва полноты ЖД-документов.
# - Ресурсные/оценочные риски по ТМ-27 и BADI: необходимость выделения времени на разработку/тест, влияние на сроки запуска разнесения затрат.
#
# 5. Повторяющиеся инциденты (объединённо)
# - Персистирующие расхождения по ВГО и обсуждения методики сверки «нарастающим итогом».
# - Повторяющиеся дискуссии по валютным кодам и требованию 1:1 в «Зеркале 2».
# - Инцидент Transporeon с невыполненной выгрузкой номера авто (6100065014) и зависанием очереди — поднимался в нескольких потоках.
# - Регулярные запросы на включение/расширение автораспределения в EWM и контроль ограничений.
# - Неоднократные обращения по доступам к поставкам ЛДК и корректной роли в матрице.
# - Наличие маршрутов ВФК в ПУТ, мешающее сверке ТО — требуется повторяющееся очищение.
# - Постоянные напоминания о финализации регламентов ТМ к 01.03.
# - Повторные запросы на создание/расширение BP для склада S015.
# - Многократные уточнения сроков запуска печати ГУ-29.
#
# 6. Финальное резюме
# Проект движется к выравниванию финансово-логистического контура: критические ЗНИ (272, 281, 239, 282) в активной фазе, часть технических мер реализована, но остаются ключевые зависимые решения. Для консолидации результата в ближайшем цикле приоритетны: финализация политики валют и доработка «Зеркала 2» под многократные ДРФ; согласование и планирование релиза ЗНИ 272; закрытие ЗНИ 281 к установленным срокам; завершение тестов и выпуск ЗНИ 239 с коммуницированными ограничениями; принятие решения по расширению EWM-автораспределения на ЖД; закрытие мастер-данных/доступов (BP S015, ЛДК); формализация и публикация регламентов ТМ; запуск регулярных статусов по ЗНИ 282; подтверждение устойчивости интеграции Transporeon; оценка и старт разработки ТМ-27 для разнесения фактических транспортных затрат. Это позволит снизить риски МСФО 15, стабилизировать ВГО и ускорить операционные процессы отгрузки.

# %%
from pipeline import EmailSummaryPipeline

pipeline = EmailSummaryPipeline(qv=qv, model="gpt-5")


class Orchestrator:
    def __init__(self, pipeline):
        self.pipeline = pipeline
        self.run_batch_tool = tool(self.run_batch)
        self.run_global_tool = tool(self.run_global)

    def run_batch(self, project_hint: str) -> str:
        """
        Запуск batch-обработки.
        """
        result = self.pipeline.run_batch_processing(project_hint)
        # agent.invoke возвращает сложный объект → извлекаем текст
        return result["messages"][-1].content

    def run_global(self, project_hint: str) -> str:
        """
        Запуск глобальной агрегации.
        """
        result = self.pipeline.run_global_summary(project_hint)
        return result["messages"][-1].content

# %%
orchestrator = Orchestrator(pipeline)

ORCH_SYSTEM_PROMPT = """
Ты — главный управляющий агент.

Твоя задача:
- понять намерение пользователя
- выбрать подходящего подчинённого агента
- нужно вызывать по порядку:
          1.  run_batch(project_hint)  — произвести batch-сбор summary
          2.  run_global(project_hint) — сделать финальное summary

Пользователь может писать в свободной форме.
Ты должен:
  - определить project_hint
  - определить, что хочет пользователь: батчи или итоговый отчёт
  - вызвать нужные инструменты
  - вернуть пользователю результат

Не выполняй анализ почты сам — всё через инструменты.
"""

main_agent = create_agent(
    # model="gpt-5.1",
    model="deepseek-reasoner",
    tools=[
        orchestrator.run_batch_tool,
        orchestrator.run_global_tool,
    ],
    system_prompt=ORCH_SYSTEM_PROMPT,
)

# %%
result = main_agent.invoke({
    "messages": [
        {"role": "user", "content": "Сделай итоговый отчёт по проекту Segezha"}
    ]
})
print(result["messages"][-1].content)
# Out:
# Итоговый отчёт по проекту Segezha
#
# 1. Краткое резюме по проекту
# Проект “Segezha” движется по нескольким ключевым трекам: исправление расхождений по ВГО (ЗНИ 281, целевая дата 5 марта), повышение корректности данных для выручки по МСФО 15 через интеграцию TM–SD (ЗНИ 272; согласовано по сути, реализация — не ранее середины марта, оценка 1–2 месяца), автоматизация распределения поставок в EWM (запущено 26.02, мониторятся исключения), а также доработки по “Зеркалу 2” для валютных счетов (правила по кодам валют и поддержка множественных ДРФ). Параллельно прорабатываются: разнесение фактических транспортных затрат (архитектура и трудозатраты), перенос хранения номера вагона (ЗНИ 239), запуск печати полного комплекта ГУ-29 для контейнеров, регламенты TM/ОП, учет вывозки сырья (ЗНИ-282), НСИ/интеграции и доступы. Основные риски — корректность учета выручки/валюты и операционные ограничения до завершения ключевых ЗНИ.
#
# 2. Основные темы
# - TM–SD и МСФО 15 (ЗНИ 272):
#   - Передача даты коносамента из TM и заполнение даты перехода рисков в исходящей поставке.
#   - Временный регламент: ежедневный мониторинг, классификация ошибок (5 типов), ручные проверки и полномочия логистов до внедрения.
#   - Доработка требует финальной спецификации со стороны сбыта; расширение покрытия по базисам поставки.
# - Расхождения по ВГО (ЗНИ 281):
#   - Сверка “нарастающим итогом” для переходящих позиций между месяцами.
#   - Курсовые разницы и кейсы EUR/UEU/RUB; ошибки привязки документов; риск неверных сумм (пример со счетом 649).
#   - Трудозатраты ~3 ч/д; целевая дата корректировок — 5 марта.
# - “Зеркало 2: валютные счета”:
#   - Нестабильность при нескольких ДРФ в одном документе (работает при одном ДРФ).
#   - Исправлено зеркалирование при двойном налогообложении; введены коды UEU/UUS вместо EUR/USD.
#   - Нужны единые правила кодов валют и подтверждение “валюта 1-в-1”; вопрос по отличиям EUR vs UEU; запрос на поддержку множественных ДРФ.
# - Автораспределение поставок (EWM/TM):
#   - Автоматическое распределение включено с 26.02 (каждые 30 минут); расширено на ЖД/контейнеры; выявляются и разбираются кейсы-исключения.
#   - Ограничение: после распределения из TM нельзя менять номер вагона до переноса ЗНИ 239.
# - Разнесение фактических транспортных затрат:
#   - Все данные приходят из TM; расширение PI не требуется.
#   - Предлагается реализация через BADI (мэппинг, пропорциональное распределение на позиции заказа, множественная контировка ОУР); оценка трудозатрат (в т.ч. ТМ-27).
#   - Обсуждается генерация цепочки документов в S/4.
# - ЗНИ 239 (номер вагона):
#   - Перенос источника номера с LIKP-TRAID в текст 1013 (“Номер трансп. средства”); ограничения на исторические поставки; тест формы “Паспорт качества” (MNF); информирование складов/логистов перед переносом.
# - Ж/Д печать ГУ-29 (СЦБК):
#   - Запрос и подтверждение даты запуска печати полного комплекта для контейнеров (ранее называлась 13/02).
# - Регламенты и НСИ/интеграции:
#   - Регламенты по ОП и НСИ ТМ — на согласовании (комментарии учтены, финализация до 01.03).
#   - “Создание БП для склада S015/1311” (альтернативный ID “код завода пробел код склада”; расширение на сбытовой ракурс).
#   - Актуализация “Приложения 1 к ТЗ” по интеграциям TM.
# - Сервисдеск/JIRA и доступы:
#   - SAPSP-17498 (EWM авто-распределение) — включено; ведется мониторинг.
#   - SAPSP-18530 (номер авто из Transporeon) — единичный сбой очереди сериализации, исправлено.
#   - SAPSP-18554 (смена экспедитора) — решено.
#   - SAPSP-18265 (доступ к поставкам Лесосибирского ЛДК) — открыт/уточняется роль, встречается перевідкрытие.
#
# 3. Ключевые решения
# - ЗНИ 281 (ВГО) согласовано; план корректировок с целевой датой 5 марта; подход к сверке “нарастающим итогом”.
# - ЗНИ 272 (TM–SD) по сути согласовано: перенос даты коносамента и даты перехода рисков; временные ручные контроли и обучение логистов до внедрения; реализация — не ранее середины марта, оценка 1–2 месяца; нужна финальная спецификация и расширение по базисам.
# - “Зеркало 2”: исправлено двойное налогообложение; введены коды UEU/UUS; подтверждена цель “валюта 1-в-1”, требуется финализировать правило и реализовать поддержку множественных ДРФ.
# - EWM: автораспределение поставок включено с 26.02 (в т.ч. ЖД/контейнеры), с 30-минутным интервалом.
# - ЗНИ 239: принято сменить источник хранения номера вагона на текст 1013; ограничение на историю; провести совместные тесты (в т.ч. MNF) и информирование операционных команд.
# - Разнесение транспортных затрат: выбрана архитектура на BADI с мэппингом структур; подтверждено, что все данные приходят в XML; оценка и планирование сценариев пропорционального разнесения и множественной контировки (ТМ-27).
#
# 4. Проблемы и риски
# - Риск некорректного признания выручки (МСФО 15) до внедрения ЗНИ 272: неверные/пустые даты перехода рисков, ошибки в заказах; снижается за счет ежедневного контроля и обучения, но полностью не устраняется до автоматизации.
# - Валютные риски по ВГО: различия UEU/EUR/UUS/USD, неверная связка документов и суммы в учете (пример переплаты по 649); требуется единое правило кодов валют и корректная привязка.
# - “Зеркало 2”: отсутствие поддержки множественных ДРФ увеличивает ручной труд и вероятность ошибок; неустойчивость при валютных кейсах без ясных правил.
# - Операционные ограничения в EWM/TM: запрет на изменение номера вагона после распределения до переноса ЗНИ 239; риск инцидентов в пиковых сценариях.
# - Задержки по финальным спецификациям/согласованиям (ЗНИ 272, регламенты TM/ОП, ГУ-29 печать) могут сдвигать сроки и увеличивать объем ручных корректировок.
# - Данные НСИ/логистические маршруты (ПУТ) и доступы: “хвосты” настроек и роли вызывают затруднения при сверках и операциях.
# - Недовнедрение сценария разнесения фактических транспортных затрат грозит некорректной аналитикой “выручка без транспорта”.
#
# 5. Повторяющиеся инциденты (объединённо)
# - Валютные несоответствия и неопределенность кодов (EUR vs UEU, USD vs UUS) → ошибки сумм/проводок и вопросы по связке документов.
# - Нестабильность “Зеркало 2” при нескольких ДРФ в одном документе → частые запросы разделять документы.
# - Исключения в автоматическом распределении (EWM/TM) и единичные сбои интеграционных очередей (Transporeon номер авто) → временные ручные действия.
# - Повторные запросы по доступам/ролям (Лесосибирский ЛДК) и перезапуски задач.
# - Регулярные вопросы по запуску печати ГУ-29 для контейнеров (требуется подтверждение даты).
# - “Сверка ТО”: затруднения из‑за неактуальных маршрутов в ПУТ.
#
# 6. Финальное резюме
# Проект последовательно закрывает системные пробелы в учете выручки и логистике: согласована и готовится к внедрению интеграция TM–SD (ЗНИ 272), выверяются внутригрупповые операции (ЗНИ 281), включено автораспределение поставок в EWM, готовится перенос хранения номера вагона (ЗНИ 239). Критические открытые темы: финализация правил по валютным кодам и поддержка множественных ДРФ в “Зеркале 2”, запуск печати ГУ-29, утверждение регламентов TM/ОП, решение по архитектуре и оценкам для разнесения транспортных затрат. Рекомендуемые ближайшие шаги: подтвердить единое правило “валюта 1-в-1” и перечень допустимых кодов, зафиксировать сроки/объем ЗНИ 272 (с конкретными базисами поставки), выпустить план миграции по ЗНИ 239 с коммуникацией на склады/логистику, согласовать дату запуска печати ГУ-29, утвердить регламенты и НСИ-изменения, а также зафиксировать план работ по ТМ-27 и пропорциональному разнесению. Это снизит риски по МСФО 15 и валютным расхождениям и уменьшит долю ручных операций.

# %% [markdown]
# ### вывод инфо

# %%
from openai import OpenAI
import os

# SDK автоматически возьмет DEEPSEEK_API_KEY если api_key=None
client = OpenAI(
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url="https://api.deepseek.com/v1"
)

response = client.chat.completions.create(
    model="deepseek-chat",
    messages=[
        {"role": "system", "content": "Ты тестовый ассистент."},
        {"role": "user", "content": "Проверка соединения. Напиши 'OK'."}
    ]
)

print(response.choices[0].message.content)
# Out:
# OK
